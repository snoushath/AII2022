# %%
import numpy as np
import h5py

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\noush\OneDrive\Noushath Data\Research\Deep Learning Codes\Python Projects\IJNS2023\DLAlgos\ResNet152

# %%
def load_OASIS():
    with h5py.File('..\..\Datasets\OASIS_balanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('trainX'))
        trainY = np.array(G1.get('trainY'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('testX'))
        testY = np.array(G2.get('testY'))

        return trainX, trainY, testX, testY

# %%
def load_ADNI():
    with h5py.File('..\..\Datasets\ADNI_enhanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('x_train'))
        trainY = np.array(G1.get('y_train'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('x_test'))
        testY = np.array(G2.get('y_test'))

        return trainX, trainY, testX, testY

# %%
dataset = 'ADNI'
#dataset = 'ADsNI'
# read the data which is also normalized.
if dataset == 'ADNI':
    x_train, y_train, x_test, y_test = load_ADNI()
else:
    x_train, y_train, x_test, y_test = load_OASIS()

print(x_train.shape, y_train.shape, x_test.shape,y_test.shape)
# Out:
# (940, 218, 182, 1) (940,) (105, 218, 182, 1) (105,)

# %%
#Dataset ready for deep learning
from tensorflow.keras.utils import to_categorical
#x_train = np.expand_dims(x_train, axis=-1)
x_train = np.repeat(x_train, 3, axis=3)

#x_test = np.expand_dims(x_test, axis=-1)
x_test = np.repeat(x_test, 3, axis=3)

y_train_cat = to_categorical(y_train, num_classes=4)
y_test_cat = to_categorical(y_test, num_classes=4)

print("Test",x_test.shape)
print ("Train",x_train.shape)
print(y_train.shape)
print (y_train_cat.shape)
print (y_test_cat.shape)
#print(np.max(x_train[0])) #to ensure that the values are within the range [0,1]
# Out:
# Test (105, 218, 182, 3)
# Train (940, 218, 182, 3)
# (940,)
# (940, 4)
# (105, 4)

# %%
print(x_test.shape)
print()
epochs = 10 #hyperparameter
num_classes=4
# Out:
# (105, 218, 182, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, MaxPooling2D, Activation, BatchNormalization
import tensorflow as tf
resnet_model = Sequential()


pretrained_model= tf.keras.applications.ResNet152(include_top=False,
                   #input_shape=(176,176,3),
                   input_shape=(218,182,3),
                   pooling='avg',classes=4,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Dropout(0.5))
resnet_model.add(Flatten())
resnet_model.add(BatchNormalization())
resnet_model.add(Dense(2048,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(1024,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(4,activation='softmax'))
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet152 (Functional)       (None, 2048)              58370944
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 2048)              4196352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 64,690,052
# Trainable params: 6,308,868
# Non-trainable params: 58,381,184
# _________________________________________________________________

# %%
METRIC = tf.keras.metrics.AUC(name = 'acc')
from tensorflow.keras.optimizers import Adam # optimizer hyperparameter
resnet_model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=METRIC) #learning rate hyperparameter.

# %%
filepath = 'best_weights.hdf5'
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

earlystopping = EarlyStopping(monitor = 'acc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'acc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)
callback_list = [earlystopping, checkpoint]

# %%
#training
#batch_size hyperparamter.
history=resnet_model.fit(x_train, y_train_cat, batch_size = 128, epochs = 200, verbose = 1, validation_data = (x_test, y_test_cat), callbacks=callback_list)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 17s 1s/step - loss: 1.6379 - acc: 0.6607 - val_loss: 2.0958 - val_acc: 0.6432
#
# Epoch 00001: acc improved from -inf to 0.66070, saving model to best_weights.hdf5
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/200
# 8/8 [==============================] - 4s 527ms/step - loss: 1.4399 - acc: 0.7711 - val_loss: 2.0355 - val_acc: 0.6639
#
# Epoch 00002: acc improved from 0.66070 to 0.77112, saving model to best_weights.hdf5
# Epoch 3/200
# 8/8 [==============================] - 4s 529ms/step - loss: 1.2884 - acc: 0.7989 - val_loss: 1.6500 - val_acc: 0.6666
#
# Epoch 00003: acc improved from 0.77112 to 0.79887, saving model to best_weights.hdf5
# Epoch 4/200
# 8/8 [==============================] - 4s 526ms/step - loss: 1.2727 - acc: 0.8001 - val_loss: 1.3695 - val_acc: 0.6764
#
# Epoch 00004: acc improved from 0.79887 to 0.80007, saving model to best_weights.hdf5
# Epoch 5/200
# 8/8 [==============================] - 4s 533ms/step - loss: 1.2559 - acc: 0.8086 - val_loss: 1.2951 - val_acc: 0.6864
#
# Epoch 00005: acc improved from 0.80007 to 0.80863, saving model to best_weights.hdf5
# Epoch 6/200
# 8/8 [==============================] - 4s 530ms/step - loss: 1.1414 - acc: 0.8329 - val_loss: 1.1837 - val_acc: 0.7143
#
# Epoch 00006: acc improved from 0.80863 to 0.83290, saving model to best_weights.hdf5
# Epoch 7/200
# 8/8 [==============================] - 4s 530ms/step - loss: 1.0759 - acc: 0.8461 - val_loss: 1.1123 - val_acc: 0.8168
#
# Epoch 00007: acc improved from 0.83290 to 0.84614, saving model to best_weights.hdf5
# Epoch 8/200
# 8/8 [==============================] - 4s 529ms/step - loss: 1.0678 - acc: 0.8441 - val_loss: 1.0997 - val_acc: 0.8394
#
# Epoch 00008: acc did not improve from 0.84614
# Epoch 9/200
# 8/8 [==============================] - 4s 531ms/step - loss: 1.0618 - acc: 0.8458 - val_loss: 1.0840 - val_acc: 0.8401
#
# Epoch 00009: acc did not improve from 0.84614
# Epoch 10/200
# 8/8 [==============================] - 4s 530ms/step - loss: 1.0487 - acc: 0.8523 - val_loss: 1.0711 - val_acc: 0.8280
#
# Epoch 00010: acc improved from 0.84614 to 0.85228, saving model to best_weights.hdf5
# Epoch 11/200
# 8/8 [==============================] - 4s 547ms/step - loss: 1.0189 - acc: 0.8560 - val_loss: 1.0782 - val_acc: 0.8324
#
# Epoch 00011: acc improved from 0.85228 to 0.85603, saving model to best_weights.hdf5
# Epoch 12/200
# 8/8 [==============================] - 4s 538ms/step - loss: 1.0194 - acc: 0.8506 - val_loss: 1.0972 - val_acc: 0.8091
#
# Epoch 00012: acc did not improve from 0.85603
# Epoch 13/200
# 8/8 [==============================] - 4s 523ms/step - loss: 0.8898 - acc: 0.8772 - val_loss: 1.1256 - val_acc: 0.7827
#
# Epoch 00013: acc improved from 0.85603 to 0.87722, saving model to best_weights.hdf5
# Epoch 14/200
# 8/8 [==============================] - 4s 524ms/step - loss: 0.8829 - acc: 0.8810 - val_loss: 1.1158 - val_acc: 0.7952
#
# Epoch 00014: acc improved from 0.87722 to 0.88095, saving model to best_weights.hdf5
# Epoch 15/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.8136 - acc: 0.8943 - val_loss: 1.1033 - val_acc: 0.8124
#
# Epoch 00015: acc improved from 0.88095 to 0.89428, saving model to best_weights.hdf5
# Epoch 16/200
# 8/8 [==============================] - 4s 526ms/step - loss: 0.8941 - acc: 0.8776 - val_loss: 1.1171 - val_acc: 0.8164
#
# Epoch 00016: acc did not improve from 0.89428
# Epoch 17/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.8546 - acc: 0.8849 - val_loss: 1.1049 - val_acc: 0.8398
#
# Epoch 00017: acc did not improve from 0.89428
# Epoch 18/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.8675 - acc: 0.8847 - val_loss: 1.0931 - val_acc: 0.8430
#
# Epoch 00018: acc did not improve from 0.89428
# Epoch 19/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.7988 - acc: 0.8978 - val_loss: 1.0829 - val_acc: 0.8492
#
# Epoch 00019: acc improved from 0.89428 to 0.89782, saving model to best_weights.hdf5
# Epoch 20/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.8127 - acc: 0.8898 - val_loss: 1.0977 - val_acc: 0.8354
#
# Epoch 00020: acc did not improve from 0.89782
# Epoch 21/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.8090 - acc: 0.8944 - val_loss: 1.1005 - val_acc: 0.8195
#
# Epoch 00021: acc did not improve from 0.89782
# Epoch 22/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.7550 - acc: 0.9060 - val_loss: 1.0935 - val_acc: 0.8162
#
# Epoch 00022: acc improved from 0.89782 to 0.90598, saving model to best_weights.hdf5
# Epoch 23/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.7255 - acc: 0.9098 - val_loss: 1.0640 - val_acc: 0.8435
#
# Epoch 00023: acc improved from 0.90598 to 0.90976, saving model to best_weights.hdf5
# Epoch 24/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.7351 - acc: 0.9109 - val_loss: 1.0543 - val_acc: 0.8464
#
# Epoch 00024: acc improved from 0.90976 to 0.91086, saving model to best_weights.hdf5
# Epoch 25/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.7187 - acc: 0.9134 - val_loss: 1.0515 - val_acc: 0.8435
#
# Epoch 00025: acc improved from 0.91086 to 0.91342, saving model to best_weights.hdf5
# Epoch 26/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.7010 - acc: 0.9176 - val_loss: 1.0356 - val_acc: 0.8497
#
# Epoch 00026: acc improved from 0.91342 to 0.91761, saving model to best_weights.hdf5
# Epoch 27/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.7111 - acc: 0.9143 - val_loss: 1.0379 - val_acc: 0.8526
#
# Epoch 00027: acc did not improve from 0.91761
# Epoch 28/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.7010 - acc: 0.9182 - val_loss: 1.0327 - val_acc: 0.8450
#
# Epoch 00028: acc improved from 0.91761 to 0.91820, saving model to best_weights.hdf5
# Epoch 29/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.7216 - acc: 0.9133 - val_loss: 1.0314 - val_acc: 0.8495
#
# Epoch 00029: acc did not improve from 0.91820
# Epoch 30/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.6787 - acc: 0.9228 - val_loss: 0.9889 - val_acc: 0.8763
#
# Epoch 00030: acc improved from 0.91820 to 0.92280, saving model to best_weights.hdf5
# Epoch 31/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.6949 - acc: 0.9172 - val_loss: 0.9784 - val_acc: 0.8753
#
# Epoch 00031: acc did not improve from 0.92280
# Epoch 32/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.6737 - acc: 0.9229 - val_loss: 0.9613 - val_acc: 0.8663
#
# Epoch 00032: acc improved from 0.92280 to 0.92292, saving model to best_weights.hdf5
# Epoch 33/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.6719 - acc: 0.9250 - val_loss: 0.9494 - val_acc: 0.8748
#
# Epoch 00033: acc improved from 0.92292 to 0.92499, saving model to best_weights.hdf5
# Epoch 34/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.5982 - acc: 0.9374 - val_loss: 0.9210 - val_acc: 0.9031
#
# Epoch 00034: acc improved from 0.92499 to 0.93744, saving model to best_weights.hdf5
# Epoch 35/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.6221 - acc: 0.9336 - val_loss: 0.9049 - val_acc: 0.8972
#
# Epoch 00035: acc did not improve from 0.93744
# Epoch 36/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.5945 - acc: 0.9385 - val_loss: 0.9075 - val_acc: 0.8904
#
# Epoch 00036: acc improved from 0.93744 to 0.93849, saving model to best_weights.hdf5
# Epoch 37/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.6473 - acc: 0.9279 - val_loss: 0.8841 - val_acc: 0.9060
#
# Epoch 00037: acc did not improve from 0.93849
# Epoch 38/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.5992 - acc: 0.9387 - val_loss: 0.8598 - val_acc: 0.9106
#
# Epoch 00038: acc improved from 0.93849 to 0.93866, saving model to best_weights.hdf5
# Epoch 39/200
# 8/8 [==============================] - 4s 526ms/step - loss: 0.5948 - acc: 0.9388 - val_loss: 0.8574 - val_acc: 0.9086
#
# Epoch 00039: acc improved from 0.93866 to 0.93877, saving model to best_weights.hdf5
# Epoch 40/200
# 8/8 [==============================] - 4s 526ms/step - loss: 0.6180 - acc: 0.9349 - val_loss: 0.8440 - val_acc: 0.9205
#
# Epoch 00040: acc did not improve from 0.93877
# Epoch 41/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.6269 - acc: 0.9333 - val_loss: 0.8203 - val_acc: 0.9205
#
# Epoch 00041: acc did not improve from 0.93877
# Epoch 42/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.6333 - acc: 0.9307 - val_loss: 0.8000 - val_acc: 0.9286
#
# Epoch 00042: acc did not improve from 0.93877
# Epoch 43/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5620 - acc: 0.9451 - val_loss: 0.7857 - val_acc: 0.9320
#
# Epoch 00043: acc improved from 0.93877 to 0.94507, saving model to best_weights.hdf5
# Epoch 44/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5788 - acc: 0.9417 - val_loss: 0.7709 - val_acc: 0.9357
#
# Epoch 00044: acc did not improve from 0.94507
# Epoch 45/200
# 8/8 [==============================] - 4s 518ms/step - loss: 0.5858 - acc: 0.9405 - val_loss: 0.7492 - val_acc: 0.9375
#
# Epoch 00045: acc did not improve from 0.94507
# Epoch 46/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5832 - acc: 0.9408 - val_loss: 0.7406 - val_acc: 0.9406
#
# Epoch 00046: acc did not improve from 0.94507
# Epoch 47/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5638 - acc: 0.9447 - val_loss: 0.7172 - val_acc: 0.9464
#
# Epoch 00047: acc did not improve from 0.94507
# Epoch 48/200
# 8/8 [==============================] - 4s 518ms/step - loss: 0.5766 - acc: 0.9428 - val_loss: 0.7056 - val_acc: 0.9517
#
# Epoch 00048: acc did not improve from 0.94507
# Epoch 49/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5676 - acc: 0.9437 - val_loss: 0.7007 - val_acc: 0.9485
#
# Epoch 00049: acc did not improve from 0.94507
# Epoch 50/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5731 - acc: 0.9441 - val_loss: 0.6805 - val_acc: 0.9517
#
# Epoch 00050: acc did not improve from 0.94507
# Epoch 51/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.5522 - acc: 0.9469 - val_loss: 0.6700 - val_acc: 0.9597
#
# Epoch 00051: acc improved from 0.94507 to 0.94689, saving model to best_weights.hdf5
# Epoch 52/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.5276 - acc: 0.9508 - val_loss: 0.6417 - val_acc: 0.9641
#
# Epoch 00052: acc improved from 0.94689 to 0.95082, saving model to best_weights.hdf5
# Epoch 53/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.5480 - acc: 0.9482 - val_loss: 0.6176 - val_acc: 0.9652
#
# Epoch 00053: acc did not improve from 0.95082
# Epoch 54/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.5391 - acc: 0.9496 - val_loss: 0.5969 - val_acc: 0.9668
#
# Epoch 00054: acc did not improve from 0.95082
# Epoch 55/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.4987 - acc: 0.9565 - val_loss: 0.5777 - val_acc: 0.9707
#
# Epoch 00055: acc improved from 0.95082 to 0.95651, saving model to best_weights.hdf5
# Epoch 56/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.5179 - acc: 0.9532 - val_loss: 0.5708 - val_acc: 0.9696
#
# Epoch 00056: acc did not improve from 0.95651
# Epoch 57/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.5037 - acc: 0.9563 - val_loss: 0.5597 - val_acc: 0.9695
#
# Epoch 00057: acc did not improve from 0.95651
# Epoch 58/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.4896 - acc: 0.9574 - val_loss: 0.5462 - val_acc: 0.9717
#
# Epoch 00058: acc improved from 0.95651 to 0.95737, saving model to best_weights.hdf5
# Epoch 59/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.5052 - acc: 0.9552 - val_loss: 0.5228 - val_acc: 0.9735
#
# Epoch 00059: acc did not improve from 0.95737
# Epoch 60/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.5062 - acc: 0.9556 - val_loss: 0.5210 - val_acc: 0.9728
#
# Epoch 00060: acc did not improve from 0.95737
# Epoch 61/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.4959 - acc: 0.9571 - val_loss: 0.5137 - val_acc: 0.9732
#
# Epoch 00061: acc did not improve from 0.95737
# Epoch 62/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.4953 - acc: 0.9575 - val_loss: 0.5006 - val_acc: 0.9745
#
# Epoch 00062: acc improved from 0.95737 to 0.95749, saving model to best_weights.hdf5
# Epoch 63/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.4887 - acc: 0.9583 - val_loss: 0.4800 - val_acc: 0.9753
#
# Epoch 00063: acc improved from 0.95749 to 0.95835, saving model to best_weights.hdf5
# Epoch 64/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.4778 - acc: 0.9597 - val_loss: 0.4714 - val_acc: 0.9747
#
# Epoch 00064: acc improved from 0.95835 to 0.95968, saving model to best_weights.hdf5
# Epoch 65/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.4797 - acc: 0.9598 - val_loss: 0.4502 - val_acc: 0.9755
#
# Epoch 00065: acc improved from 0.95968 to 0.95977, saving model to best_weights.hdf5
# Epoch 66/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.4840 - acc: 0.9587 - val_loss: 0.4454 - val_acc: 0.9769
#
# Epoch 00066: acc did not improve from 0.95977
# Epoch 67/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.4617 - acc: 0.9627 - val_loss: 0.4366 - val_acc: 0.9775
#
# Epoch 00067: acc improved from 0.95977 to 0.96272, saving model to best_weights.hdf5
# Epoch 68/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.4426 - acc: 0.9656 - val_loss: 0.4218 - val_acc: 0.9782
#
# Epoch 00068: acc improved from 0.96272 to 0.96557, saving model to best_weights.hdf5
# Epoch 69/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.4854 - acc: 0.9588 - val_loss: 0.4035 - val_acc: 0.9806
#
# Epoch 00069: acc did not improve from 0.96557
# Epoch 70/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.5255 - acc: 0.9515 - val_loss: 0.3908 - val_acc: 0.9808
#
# Epoch 00070: acc did not improve from 0.96557
# Epoch 71/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.4446 - acc: 0.9656 - val_loss: 0.3773 - val_acc: 0.9805
#
# Epoch 00071: acc improved from 0.96557 to 0.96561, saving model to best_weights.hdf5
# Epoch 72/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.4656 - acc: 0.9620 - val_loss: 0.3733 - val_acc: 0.9798
#
# Epoch 00072: acc did not improve from 0.96561
# Epoch 73/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.4579 - acc: 0.9632 - val_loss: 0.3759 - val_acc: 0.9778
#
# Epoch 00073: acc did not improve from 0.96561
# Epoch 74/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.4735 - acc: 0.9602 - val_loss: 0.3727 - val_acc: 0.9773
#
# Epoch 00074: acc did not improve from 0.96561
# Epoch 75/200
# 8/8 [==============================] - 4s 523ms/step - loss: 0.4426 - acc: 0.9652 - val_loss: 0.3553 - val_acc: 0.9784
#
# Epoch 00075: acc did not improve from 0.96561
# Epoch 76/200
# 8/8 [==============================] - 4s 519ms/step - loss: 0.4299 - acc: 0.9674 - val_loss: 0.3430 - val_acc: 0.9799
#
# Epoch 00076: acc improved from 0.96561 to 0.96742, saving model to best_weights.hdf5
# Epoch 77/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.4320 - acc: 0.9665 - val_loss: 0.3307 - val_acc: 0.9813
#
# Epoch 00077: acc did not improve from 0.96742
# Epoch 78/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.4551 - acc: 0.9638 - val_loss: 0.3206 - val_acc: 0.9809
#
# Epoch 00078: acc did not improve from 0.96742
# Epoch 79/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.4569 - acc: 0.9630 - val_loss: 0.3251 - val_acc: 0.9794
#
# Epoch 00079: acc did not improve from 0.96742
# Epoch 80/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.4424 - acc: 0.9654 - val_loss: 0.3278 - val_acc: 0.9779
#
# Epoch 00080: acc did not improve from 0.96742
# Epoch 81/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.3848 - acc: 0.9737 - val_loss: 0.3135 - val_acc: 0.9800
#
# Epoch 00081: acc improved from 0.96742 to 0.97374, saving model to best_weights.hdf5
# Epoch 82/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.4146 - acc: 0.9698 - val_loss: 0.2933 - val_acc: 0.9823
#
# Epoch 00082: acc did not improve from 0.97374
# Epoch 83/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.4306 - acc: 0.9676 - val_loss: 0.2897 - val_acc: 0.9824
#
# Epoch 00083: acc did not improve from 0.97374
# Epoch 84/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.4358 - acc: 0.9662 - val_loss: 0.2862 - val_acc: 0.9824
#
# Epoch 00084: acc did not improve from 0.97374
# Epoch 85/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3813 - acc: 0.9749 - val_loss: 0.2728 - val_acc: 0.9827
#
# Epoch 00085: acc improved from 0.97374 to 0.97486, saving model to best_weights.hdf5
# Epoch 86/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.3802 - acc: 0.9743 - val_loss: 0.2736 - val_acc: 0.9815
#
# Epoch 00086: acc did not improve from 0.97486
# Epoch 87/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.3791 - acc: 0.9745 - val_loss: 0.2668 - val_acc: 0.9811
#
# Epoch 00087: acc did not improve from 0.97486
# Epoch 88/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.4050 - acc: 0.9706 - val_loss: 0.2536 - val_acc: 0.9864
#
# Epoch 00088: acc did not improve from 0.97486
# Epoch 89/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3904 - acc: 0.9727 - val_loss: 0.2589 - val_acc: 0.9846
#
# Epoch 00089: acc did not improve from 0.97486
# Epoch 90/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3862 - acc: 0.9726 - val_loss: 0.2511 - val_acc: 0.9862
#
# Epoch 00090: acc did not improve from 0.97486
# Epoch 91/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3490 - acc: 0.9782 - val_loss: 0.2357 - val_acc: 0.9871
#
# Epoch 00091: acc improved from 0.97486 to 0.97823, saving model to best_weights.hdf5
# Epoch 92/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.3727 - acc: 0.9757 - val_loss: 0.2393 - val_acc: 0.9856
#
# Epoch 00092: acc did not improve from 0.97823
# Epoch 93/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.3962 - acc: 0.9721 - val_loss: 0.2506 - val_acc: 0.9824
#
# Epoch 00093: acc did not improve from 0.97823
# Epoch 94/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.3627 - acc: 0.9765 - val_loss: 0.2553 - val_acc: 0.9826
#
# Epoch 00094: acc did not improve from 0.97823
# Epoch 95/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.3848 - acc: 0.9736 - val_loss: 0.2387 - val_acc: 0.9836
#
# Epoch 00095: acc did not improve from 0.97823
# Epoch 96/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3777 - acc: 0.9742 - val_loss: 0.2249 - val_acc: 0.9842
#
# Epoch 00096: acc did not improve from 0.97823
# Epoch 97/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3492 - acc: 0.9779 - val_loss: 0.2099 - val_acc: 0.9892
#
# Epoch 00097: acc did not improve from 0.97823
# Epoch 98/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3449 - acc: 0.9788 - val_loss: 0.2021 - val_acc: 0.9897
#
# Epoch 00098: acc improved from 0.97823 to 0.97879, saving model to best_weights.hdf5
# Epoch 99/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.3593 - acc: 0.9773 - val_loss: 0.1878 - val_acc: 0.9904
#
# Epoch 00099: acc did not improve from 0.97879
# Epoch 100/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.3743 - acc: 0.9750 - val_loss: 0.1822 - val_acc: 0.9911
#
# Epoch 00100: acc did not improve from 0.97879
# Epoch 101/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.3666 - acc: 0.9760 - val_loss: 0.1954 - val_acc: 0.9875
#
# Epoch 00101: acc did not improve from 0.97879
# Epoch 102/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.3643 - acc: 0.9766 - val_loss: 0.2078 - val_acc: 0.9857
#
# Epoch 00102: acc did not improve from 0.97879
# Epoch 103/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3401 - acc: 0.9795 - val_loss: 0.1972 - val_acc: 0.9863
#
# Epoch 00103: acc improved from 0.97879 to 0.97953, saving model to best_weights.hdf5
# Epoch 104/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.3572 - acc: 0.9769 - val_loss: 0.1943 - val_acc: 0.9869
#
# Epoch 00104: acc did not improve from 0.97953
# Epoch 105/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.3376 - acc: 0.9798 - val_loss: 0.1855 - val_acc: 0.9862
#
# Epoch 00105: acc improved from 0.97953 to 0.97975, saving model to best_weights.hdf5
# Epoch 106/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.3883 - acc: 0.9733 - val_loss: 0.1838 - val_acc: 0.9890
#
# Epoch 00106: acc did not improve from 0.97975
# Epoch 107/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3562 - acc: 0.9775 - val_loss: 0.1918 - val_acc: 0.9846
#
# Epoch 00107: acc did not improve from 0.97975
# Epoch 108/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3472 - acc: 0.9775 - val_loss: 0.2008 - val_acc: 0.9850
#
# Epoch 00108: acc did not improve from 0.97975
# Epoch 109/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.3680 - acc: 0.9761 - val_loss: 0.1884 - val_acc: 0.9822
#
# Epoch 00109: acc did not improve from 0.97975
# Epoch 110/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3681 - acc: 0.9756 - val_loss: 0.1829 - val_acc: 0.9870
#
# Epoch 00110: acc did not improve from 0.97975
# Epoch 111/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.3063 - acc: 0.9830 - val_loss: 0.1715 - val_acc: 0.9878
#
# Epoch 00111: acc improved from 0.97975 to 0.98297, saving model to best_weights.hdf5
# Epoch 112/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.2991 - acc: 0.9836 - val_loss: 0.1698 - val_acc: 0.9922
#
# Epoch 00112: acc improved from 0.98297 to 0.98355, saving model to best_weights.hdf5
# Epoch 113/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.3416 - acc: 0.9791 - val_loss: 0.1846 - val_acc: 0.9877
#
# Epoch 00113: acc did not improve from 0.98355
# Epoch 114/200
# 8/8 [==============================] - 4s 531ms/step - loss: 0.3172 - acc: 0.9816 - val_loss: 0.1704 - val_acc: 0.9889
#
# Epoch 00114: acc did not improve from 0.98355
# Epoch 115/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.3221 - acc: 0.9807 - val_loss: 0.1567 - val_acc: 0.9894
#
# Epoch 00115: acc did not improve from 0.98355
# Epoch 116/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.3111 - acc: 0.9820 - val_loss: 0.1720 - val_acc: 0.9883
#
# Epoch 00116: acc did not improve from 0.98355
# Epoch 117/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.3029 - acc: 0.9834 - val_loss: 0.1767 - val_acc: 0.9872
#
# Epoch 00117: acc did not improve from 0.98355
# Epoch 118/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2942 - acc: 0.9840 - val_loss: 0.1770 - val_acc: 0.9868
#
# Epoch 00118: acc improved from 0.98355 to 0.98405, saving model to best_weights.hdf5
# Epoch 119/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3180 - acc: 0.9816 - val_loss: 0.1664 - val_acc: 0.9878
#
# Epoch 00119: acc did not improve from 0.98405
# Epoch 120/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.2820 - acc: 0.9860 - val_loss: 0.1568 - val_acc: 0.9923
#
# Epoch 00120: acc improved from 0.98405 to 0.98601, saving model to best_weights.hdf5
# Epoch 121/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.3228 - acc: 0.9816 - val_loss: 0.1577 - val_acc: 0.9924
#
# Epoch 00121: acc did not improve from 0.98601
# Epoch 122/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.3073 - acc: 0.9825 - val_loss: 0.1671 - val_acc: 0.9875
#
# Epoch 00122: acc did not improve from 0.98601
# Epoch 123/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.3072 - acc: 0.9831 - val_loss: 0.1656 - val_acc: 0.9888
#
# Epoch 00123: acc did not improve from 0.98601
# Epoch 124/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2949 - acc: 0.9843 - val_loss: 0.1502 - val_acc: 0.9894
#
# Epoch 00124: acc did not improve from 0.98601
# Epoch 125/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.2742 - acc: 0.9865 - val_loss: 0.1421 - val_acc: 0.9894
#
# Epoch 00125: acc improved from 0.98601 to 0.98648, saving model to best_weights.hdf5
# Epoch 126/200
# 8/8 [==============================] - 4s 527ms/step - loss: 0.3004 - acc: 0.9838 - val_loss: 0.1481 - val_acc: 0.9886
#
# Epoch 00126: acc did not improve from 0.98648
# Epoch 127/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.2814 - acc: 0.9854 - val_loss: 0.1513 - val_acc: 0.9887
#
# Epoch 00127: acc did not improve from 0.98648
# Epoch 128/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.2784 - acc: 0.9859 - val_loss: 0.1450 - val_acc: 0.9894
#
# Epoch 00128: acc did not improve from 0.98648
# Epoch 129/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2796 - acc: 0.9860 - val_loss: 0.1454 - val_acc: 0.9900
#
# Epoch 00129: acc did not improve from 0.98648
# Epoch 130/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2535 - acc: 0.9886 - val_loss: 0.1474 - val_acc: 0.9900
#
# Epoch 00130: acc improved from 0.98648 to 0.98863, saving model to best_weights.hdf5
# Epoch 131/200
# 8/8 [==============================] - 4s 529ms/step - loss: 0.2885 - acc: 0.9839 - val_loss: 0.1544 - val_acc: 0.9854
#
# Epoch 00131: acc did not improve from 0.98863
# Epoch 132/200
# 8/8 [==============================] - 4s 534ms/step - loss: 0.2791 - acc: 0.9849 - val_loss: 0.1546 - val_acc: 0.9854
#
# Epoch 00132: acc did not improve from 0.98863
# Epoch 133/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.2757 - acc: 0.9858 - val_loss: 0.1766 - val_acc: 0.9855
#
# Epoch 00133: acc did not improve from 0.98863
# Epoch 134/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2971 - acc: 0.9835 - val_loss: 0.1854 - val_acc: 0.9859
#
# Epoch 00134: acc did not improve from 0.98863
# Epoch 135/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2650 - acc: 0.9868 - val_loss: 0.1799 - val_acc: 0.9857
#
# Epoch 00135: acc did not improve from 0.98863
# Epoch 136/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2905 - acc: 0.9849 - val_loss: 0.1764 - val_acc: 0.9858
#
# Epoch 00136: acc did not improve from 0.98863
# Epoch 137/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2311 - acc: 0.9904 - val_loss: 0.1662 - val_acc: 0.9854
#
# Epoch 00137: acc improved from 0.98863 to 0.99042, saving model to best_weights.hdf5
# Epoch 138/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.2534 - acc: 0.9883 - val_loss: 0.1517 - val_acc: 0.9856
#
# Epoch 00138: acc did not improve from 0.99042
# Epoch 139/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.2810 - acc: 0.9847 - val_loss: 0.1406 - val_acc: 0.9898
#
# Epoch 00139: acc did not improve from 0.99042
# Epoch 140/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.2380 - acc: 0.9900 - val_loss: 0.1451 - val_acc: 0.9898
#
# Epoch 00140: acc did not improve from 0.99042
# Epoch 141/200
# 8/8 [==============================] - 4s 533ms/step - loss: 0.2565 - acc: 0.9878 - val_loss: 0.1565 - val_acc: 0.9858
#
# Epoch 00141: acc did not improve from 0.99042
# Epoch 142/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2983 - acc: 0.9832 - val_loss: 0.1471 - val_acc: 0.9907
#
# Epoch 00142: acc did not improve from 0.99042
# Epoch 143/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2635 - acc: 0.9871 - val_loss: 0.1717 - val_acc: 0.9858
#
# Epoch 00143: acc did not improve from 0.99042
# Epoch 144/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.3020 - acc: 0.9827 - val_loss: 0.1724 - val_acc: 0.9906
#
# Epoch 00144: acc did not improve from 0.99042
# Epoch 145/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2192 - acc: 0.9915 - val_loss: 0.1677 - val_acc: 0.9911
#
# Epoch 00145: acc improved from 0.99042 to 0.99146, saving model to best_weights.hdf5
# Epoch 146/200
# 8/8 [==============================] - 4s 528ms/step - loss: 0.2267 - acc: 0.9909 - val_loss: 0.1700 - val_acc: 0.9916
#
# Epoch 00146: acc did not improve from 0.99146
# Epoch 147/200
# 8/8 [==============================] - 4s 532ms/step - loss: 0.2479 - acc: 0.9885 - val_loss: 0.1796 - val_acc: 0.9914
#
# Epoch 00147: acc did not improve from 0.99146
# Epoch 148/200
# 8/8 [==============================] - 4s 530ms/step - loss: 0.2527 - acc: 0.9877 - val_loss: 0.2171 - val_acc: 0.9899
#
# Epoch 00148: acc did not improve from 0.99146
# Epoch 149/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2686 - acc: 0.9867 - val_loss: 0.2260 - val_acc: 0.9903
#
# Epoch 00149: acc did not improve from 0.99146
# Epoch 150/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.2764 - acc: 0.9858 - val_loss: 0.2174 - val_acc: 0.9910
#
# Epoch 00150: acc did not improve from 0.99146
# Epoch 151/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2631 - acc: 0.9866 - val_loss: 0.2000 - val_acc: 0.9911
#
# Epoch 00151: acc did not improve from 0.99146
# Epoch 152/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2472 - acc: 0.9889 - val_loss: 0.1713 - val_acc: 0.9905
#
# Epoch 00152: acc did not improve from 0.99146
# Epoch 153/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2799 - acc: 0.9857 - val_loss: 0.1604 - val_acc: 0.9912
#
# Epoch 00153: acc did not improve from 0.99146
# Epoch 154/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2400 - acc: 0.9891 - val_loss: 0.1560 - val_acc: 0.9913
#
# Epoch 00154: acc did not improve from 0.99146
# Epoch 155/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2224 - acc: 0.9909 - val_loss: 0.1585 - val_acc: 0.9901
#
# Epoch 00155: acc did not improve from 0.99146
# Epoch 156/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2460 - acc: 0.9887 - val_loss: 0.1640 - val_acc: 0.9886
#
# Epoch 00156: acc did not improve from 0.99146
# Epoch 157/200
# 8/8 [==============================] - 4s 522ms/step - loss: 0.2686 - acc: 0.9862 - val_loss: 0.1680 - val_acc: 0.9886
#
# Epoch 00157: acc did not improve from 0.99146
# Epoch 158/200
# 8/8 [==============================] - 4s 520ms/step - loss: 0.2666 - acc: 0.9864 - val_loss: 0.1575 - val_acc: 0.9887
#
# Epoch 00158: acc did not improve from 0.99146
# Epoch 159/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2652 - acc: 0.9873 - val_loss: 0.1589 - val_acc: 0.9889
#
# Epoch 00159: acc did not improve from 0.99146
# Epoch 160/200
# 8/8 [==============================] - 4s 521ms/step - loss: 0.2309 - acc: 0.9904 - val_loss: 0.1508 - val_acc: 0.9898
#
# Epoch 00160: acc did not improve from 0.99146
# Epoch 00160: early stopping

# %%
import pandas as pd
df = pd.DataFrame(history.history)
df.head()
# losses[['acc','val_acc']].plot()
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,1,sharex=True, figsize=(10,8))
ax[0].plot(df['loss'],label = 'Training Loss')
ax[0].plot(df['val_loss'],label = 'Validation Loss')
ax[1].plot(df['acc'],label = 'Training Accuracy')
ax[1].plot(df['val_acc'],label = 'Validation Accuracy')
ax[0].legend(loc='best',prop={'size':12})
ax[1].legend(loc='best',prop={'size':12})
ax[0].minorticks_on()
ax[1].minorticks_on()
ax[1].set_xlabel('Epochs', fontsize=12)
ax[1].set_ylabel('Accuracy', fontsize=12)
ax[0].set_ylabel('Loss', fontsize=12)
ax[0].grid()
ax[1].grid()
plt.show()

#saving the results
df.to_csv('results.csv')




# print(history.history['val_loss'])
# print(history.history['val_acc'])
# print(history.history['acc'])
# print(history.history['loss'])

# %%
from sklearn.metrics import multilabel_confusion_matrix
#%%
prediction = resnet_model.predict_classes(x_test)

mcm = multilabel_confusion_matrix(y_true=y_test, y_pred=prediction, labels=[0,1,2,3], samplewise=False)
tn = mcm[:,0,0]
tp = mcm[:,1,1]
fp = mcm[:,0,1]
fn = mcm[:,1,0]
specificity = tn/(tn+fp)
print("Specificity or TNR", np.mean(specificity))

sensitivity = tp/(tp+fn)
print("Sensitivity or TPR or Recall", np.mean(sensitivity))

print("FNR ", 1-np.mean(sensitivity))

print("FPR", 1-np.mean(specificity))

from sklearn import metrics
print("Accuracy = ", metrics.accuracy_score(y_test, prediction))
#%%
# use model to predict probability that given y value is 1
y_pred_proba = resnet_model.predict_proba(x_test)

#calculate AUC of model
auc = metrics.roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

#print AUC score
print("AUC =",auc)

from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test, prediction)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7, 6))
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, cmap='Blues', cbar=False, linewidth=0.5,linecolor="black",fmt='')
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
# Out:
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Specificity or TNR 0.9925575836592786
# Sensitivity or TPR or Recall 0.9803240740740741
# FNR  0.01967592592592593
# FPR 0.007442416340721403
# Accuracy =  0.9809523809523809
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:430: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# AUC = 0.9898499097687462
# Text(58.222222222222214, 0.5, 'True Label')
