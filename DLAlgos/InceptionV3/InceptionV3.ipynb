# %%
import numpy as np
import h5py

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\noush\OneDrive\Noushath Data\Research\Deep Learning Codes\Python Projects\IJNS2023\DLAlgos\InceptionV3

# %%
def load_OASIS():
    with h5py.File('..\..\Datasets\OASIS_balanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('trainX'))
        trainY = np.array(G1.get('trainY'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('testX'))
        testY = np.array(G2.get('testY'))

        return trainX, trainY, testX, testY

# %%
def load_ADNI():
    with h5py.File('..\..\Datasets\ADNI_enhanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('x_train'))
        trainY = np.array(G1.get('y_train'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('x_test'))
        testY = np.array(G2.get('y_test'))

        return trainX, trainY, testX, testY

# %%
dataset = 'ADNI'
#dataset = 'ADsNI'
# read the data which is also normalized.
if dataset == 'ADNI':
    x_train, y_train, x_test, y_test = load_ADNI()
else:
    x_train, y_train, x_test, y_test = load_OASIS()

print(x_train.shape, y_train.shape, x_test.shape,y_test.shape)
# Out:
# (940, 218, 182, 1) (940,) (105, 218, 182, 1) (105,)

# %%
#Dataset ready for deep learning
from tensorflow.keras.utils import to_categorical
#x_train = np.expand_dims(x_train, axis=-1)
x_train = np.repeat(x_train, 3, axis=3)

#x_test = np.expand_dims(x_test, axis=-1)
x_test = np.repeat(x_test, 3, axis=3)

y_train_cat = to_categorical(y_train, num_classes=4)
y_test_cat = to_categorical(y_test, num_classes=4)

print("Test",x_test.shape)
print ("Train",x_train.shape)
print(y_train.shape)
print (y_train_cat.shape)
print (y_test_cat.shape)
#print(np.max(x_train[0])) #to ensure that the values are within the range [0,1]
# Out:
# Test (105, 218, 182, 3)
# Train (940, 218, 182, 3)
# (940,)
# (940, 4)
# (105, 4)

# %%
print(x_test.shape)
print()
epochs = 10 #hyperparameter
num_classes=4
# Out:
# (105, 218, 182, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, MaxPooling2D, Activation, BatchNormalization
import tensorflow as tf
resnet_model = Sequential()


pretrained_model= tf.keras.applications.InceptionV3(include_top=False,
                   #input_shape=(176,176,3),
                   input_shape=(218,182,3),
                   pooling='avg',classes=4,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Dropout(0.5))
resnet_model.add(Flatten())
resnet_model.add(BatchNormalization())
resnet_model.add(Dense(2048,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(1024,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(4,activation='softmax'))
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 2048)              21802784
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 2048)              4196352
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 2048)              8192
# _________________________________________________________________
# activation_94 (Activation)   (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 1024)              4096
# _________________________________________________________________
# activation_95 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 28,121,892
# Trainable params: 6,308,868
# Non-trainable params: 21,813,024
# _________________________________________________________________

# %%
METRIC = tf.keras.metrics.AUC(name = 'acc')
from tensorflow.keras.optimizers import Adam # optimizer hyperparameter
resnet_model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=METRIC) #learning rate hyperparameter.

# %%
filepath = 'best_weights.hdf5'
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

earlystopping = EarlyStopping(monitor = 'acc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'acc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)
callback_list = [earlystopping, checkpoint]

# %%
#training
#batch_size hyperparamter.
history=resnet_model.fit(x_train, y_train_cat, batch_size = 128, epochs = 200, verbose = 1, validation_data = (x_test, y_test_cat), callbacks=callback_list)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 12s 687ms/step - loss: 1.5425 - acc: 0.6865 - val_loss: 2.5180 - val_acc: 0.7555
#
# Epoch 00001: acc improved from -inf to 0.68646, saving model to best_weights.hdf5
# Epoch 2/200
# 8/8 [==============================] - 1s 143ms/step - loss: 1.0711 - acc: 0.8485 - val_loss: 3.0611 - val_acc: 0.7634
#
# Epoch 00002: acc improved from 0.68646 to 0.84850, saving model to best_weights.hdf5
# Epoch 3/200
# 8/8 [==============================] - 1s 137ms/step - loss: 0.8496 - acc: 0.8945 - val_loss: 2.4935 - val_acc: 0.8065
#
# Epoch 00003: acc improved from 0.84850 to 0.89455, saving model to best_weights.hdf5
# Epoch 4/200
# 8/8 [==============================] - 1s 139ms/step - loss: 0.7991 - acc: 0.9079 - val_loss: 2.0289 - val_acc: 0.8202
#
# Epoch 00004: acc improved from 0.89455 to 0.90790, saving model to best_weights.hdf5
# Epoch 5/200
# 8/8 [==============================] - 1s 137ms/step - loss: 0.5982 - acc: 0.9407 - val_loss: 1.8416 - val_acc: 0.8499
#
# Epoch 00005: acc improved from 0.90790 to 0.94068, saving model to best_weights.hdf5
# Epoch 6/200
# 8/8 [==============================] - 1s 137ms/step - loss: 0.5415 - acc: 0.9509 - val_loss: 1.5924 - val_acc: 0.8597
#
# Epoch 00006: acc improved from 0.94068 to 0.95091, saving model to best_weights.hdf5
# Epoch 7/200
# 8/8 [==============================] - 1s 137ms/step - loss: 0.4787 - acc: 0.9594 - val_loss: 1.4150 - val_acc: 0.8747
#
# Epoch 00007: acc improved from 0.95091 to 0.95945, saving model to best_weights.hdf5
# Epoch 8/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.4413 - acc: 0.9659 - val_loss: 0.9373 - val_acc: 0.9094
#
# Epoch 00008: acc improved from 0.95945 to 0.96585, saving model to best_weights.hdf5
# Epoch 9/200
# 8/8 [==============================] - 1s 155ms/step - loss: 0.4708 - acc: 0.9620 - val_loss: 0.7909 - val_acc: 0.9296
#
# Epoch 00009: acc did not improve from 0.96585
# Epoch 10/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.4222 - acc: 0.9688 - val_loss: 0.7766 - val_acc: 0.9418
#
# Epoch 00010: acc improved from 0.96585 to 0.96880, saving model to best_weights.hdf5
# Epoch 11/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.4164 - acc: 0.9702 - val_loss: 0.6673 - val_acc: 0.9497
#
# Epoch 00011: acc improved from 0.96880 to 0.97024, saving model to best_weights.hdf5
# Epoch 12/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3742 - acc: 0.9741 - val_loss: 0.6300 - val_acc: 0.9596
#
# Epoch 00012: acc improved from 0.97024 to 0.97406, saving model to best_weights.hdf5
# Epoch 13/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2890 - acc: 0.9842 - val_loss: 0.5001 - val_acc: 0.9681
#
# Epoch 00013: acc improved from 0.97406 to 0.98424, saving model to best_weights.hdf5
# Epoch 14/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.3470 - acc: 0.9772 - val_loss: 0.3808 - val_acc: 0.9762
#
# Epoch 00014: acc did not improve from 0.98424
# Epoch 15/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3288 - acc: 0.9806 - val_loss: 0.3280 - val_acc: 0.9777
#
# Epoch 00015: acc did not improve from 0.98424
# Epoch 16/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3220 - acc: 0.9807 - val_loss: 0.2889 - val_acc: 0.9820
#
# Epoch 00016: acc did not improve from 0.98424
# Epoch 17/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2973 - acc: 0.9828 - val_loss: 0.2956 - val_acc: 0.9831
#
# Epoch 00017: acc did not improve from 0.98424
# Epoch 18/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2627 - acc: 0.9855 - val_loss: 0.3060 - val_acc: 0.9778
#
# Epoch 00018: acc improved from 0.98424 to 0.98552, saving model to best_weights.hdf5
# Epoch 19/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.2578 - acc: 0.9869 - val_loss: 0.3143 - val_acc: 0.9776
#
# Epoch 00019: acc improved from 0.98552 to 0.98689, saving model to best_weights.hdf5
# Epoch 20/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.2862 - acc: 0.9837 - val_loss: 0.2795 - val_acc: 0.9802
#
# Epoch 00020: acc did not improve from 0.98689
# Epoch 21/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2176 - acc: 0.9916 - val_loss: 0.2988 - val_acc: 0.9812
#
# Epoch 00021: acc improved from 0.98689 to 0.99156, saving model to best_weights.hdf5
# Epoch 22/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2294 - acc: 0.9893 - val_loss: 0.3166 - val_acc: 0.9798
#
# Epoch 00022: acc did not improve from 0.99156
# Epoch 23/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2208 - acc: 0.9910 - val_loss: 0.3158 - val_acc: 0.9788
#
# Epoch 00023: acc did not improve from 0.99156
# Epoch 24/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1945 - acc: 0.9926 - val_loss: 0.3081 - val_acc: 0.9801
#
# Epoch 00024: acc improved from 0.99156 to 0.99261, saving model to best_weights.hdf5
# Epoch 25/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2274 - acc: 0.9905 - val_loss: 0.3533 - val_acc: 0.9741
#
# Epoch 00025: acc did not improve from 0.99261
# Epoch 26/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2385 - acc: 0.9890 - val_loss: 0.3341 - val_acc: 0.9790
#
# Epoch 00026: acc did not improve from 0.99261
# Epoch 27/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2375 - acc: 0.9885 - val_loss: 0.2902 - val_acc: 0.9850
#
# Epoch 00027: acc did not improve from 0.99261
# Epoch 28/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2150 - acc: 0.9910 - val_loss: 0.2711 - val_acc: 0.9817
#
# Epoch 00028: acc did not improve from 0.99261
# Epoch 29/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1577 - acc: 0.9947 - val_loss: 0.2820 - val_acc: 0.9819
#
# Epoch 00029: acc improved from 0.99261 to 0.99468, saving model to best_weights.hdf5
# Epoch 30/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2145 - acc: 0.9913 - val_loss: 0.2965 - val_acc: 0.9819
#
# Epoch 00030: acc did not improve from 0.99468
# Epoch 31/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1646 - acc: 0.9949 - val_loss: 0.2920 - val_acc: 0.9823
#
# Epoch 00031: acc improved from 0.99468 to 0.99487, saving model to best_weights.hdf5
# Epoch 32/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1907 - acc: 0.9921 - val_loss: 0.2923 - val_acc: 0.9833
#
# Epoch 00032: acc did not improve from 0.99487
# Epoch 33/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1660 - acc: 0.9948 - val_loss: 0.3043 - val_acc: 0.9824
#
# Epoch 00033: acc did not improve from 0.99487
# Epoch 34/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1754 - acc: 0.9941 - val_loss: 0.3173 - val_acc: 0.9810
#
# Epoch 00034: acc did not improve from 0.99487
# Epoch 35/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1675 - acc: 0.9936 - val_loss: 0.3256 - val_acc: 0.9818
#
# Epoch 00035: acc did not improve from 0.99487
# Epoch 36/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1499 - acc: 0.9949 - val_loss: 0.3091 - val_acc: 0.9821
#
# Epoch 00036: acc improved from 0.99487 to 0.99495, saving model to best_weights.hdf5
# Epoch 37/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1260 - acc: 0.9965 - val_loss: 0.3411 - val_acc: 0.9807
#
# Epoch 00037: acc improved from 0.99495 to 0.99650, saving model to best_weights.hdf5
# Epoch 38/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1178 - acc: 0.9974 - val_loss: 0.3350 - val_acc: 0.9805
#
# Epoch 00038: acc improved from 0.99650 to 0.99744, saving model to best_weights.hdf5
# Epoch 39/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1458 - acc: 0.9959 - val_loss: 0.3567 - val_acc: 0.9762
#
# Epoch 00039: acc did not improve from 0.99744
# Epoch 40/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1748 - acc: 0.9929 - val_loss: 0.3548 - val_acc: 0.9775
#
# Epoch 00040: acc did not improve from 0.99744
# Epoch 41/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1472 - acc: 0.9959 - val_loss: 0.3580 - val_acc: 0.9780
#
# Epoch 00041: acc did not improve from 0.99744
# Epoch 42/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1431 - acc: 0.9956 - val_loss: 0.3798 - val_acc: 0.9770
#
# Epoch 00042: acc did not improve from 0.99744
# Epoch 43/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1481 - acc: 0.9953 - val_loss: 0.3881 - val_acc: 0.9713
#
# Epoch 00043: acc did not improve from 0.99744
# Epoch 44/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1381 - acc: 0.9961 - val_loss: 0.3820 - val_acc: 0.9771
#
# Epoch 00044: acc did not improve from 0.99744
# Epoch 45/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1185 - acc: 0.9971 - val_loss: 0.3592 - val_acc: 0.9773
#
# Epoch 00045: acc did not improve from 0.99744
# Epoch 46/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1097 - acc: 0.9976 - val_loss: 0.3602 - val_acc: 0.9779
#
# Epoch 00046: acc improved from 0.99744 to 0.99759, saving model to best_weights.hdf5
# Epoch 47/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0706 - acc: 0.9992 - val_loss: 0.3733 - val_acc: 0.9762
#
# Epoch 00047: acc improved from 0.99759 to 0.99919, saving model to best_weights.hdf5
# Epoch 48/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1225 - acc: 0.9967 - val_loss: 0.3667 - val_acc: 0.9777
#
# Epoch 00048: acc did not improve from 0.99919
# Epoch 49/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1082 - acc: 0.9978 - val_loss: 0.3949 - val_acc: 0.9719
#
# Epoch 00049: acc did not improve from 0.99919
# Epoch 50/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1052 - acc: 0.9969 - val_loss: 0.3866 - val_acc: 0.9775
#
# Epoch 00050: acc did not improve from 0.99919
# Epoch 51/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1149 - acc: 0.9969 - val_loss: 0.3657 - val_acc: 0.9836
#
# Epoch 00051: acc did not improve from 0.99919
# Epoch 52/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0940 - acc: 0.9982 - val_loss: 0.3564 - val_acc: 0.9793
#
# Epoch 00052: acc did not improve from 0.99919
# Epoch 53/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0978 - acc: 0.9972 - val_loss: 0.3621 - val_acc: 0.9789
#
# Epoch 00053: acc did not improve from 0.99919
# Epoch 54/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0954 - acc: 0.9978 - val_loss: 0.3638 - val_acc: 0.9774
#
# Epoch 00054: acc did not improve from 0.99919
# Epoch 55/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0907 - acc: 0.9983 - val_loss: 0.3478 - val_acc: 0.9768
#
# Epoch 00055: acc did not improve from 0.99919
# Epoch 56/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1169 - acc: 0.9973 - val_loss: 0.3325 - val_acc: 0.9780
#
# Epoch 00056: acc did not improve from 0.99919
# Epoch 57/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1039 - acc: 0.9974 - val_loss: 0.3523 - val_acc: 0.9774
#
# Epoch 00057: acc did not improve from 0.99919
# Epoch 58/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1008 - acc: 0.9974 - val_loss: 0.3800 - val_acc: 0.9770
#
# Epoch 00058: acc did not improve from 0.99919
# Epoch 59/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1003 - acc: 0.9978 - val_loss: 0.3808 - val_acc: 0.9776
#
# Epoch 00059: acc did not improve from 0.99919
# Epoch 60/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0887 - acc: 0.9986 - val_loss: 0.3479 - val_acc: 0.9778
#
# Epoch 00060: acc did not improve from 0.99919
# Epoch 61/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1149 - acc: 0.9962 - val_loss: 0.3541 - val_acc: 0.9827
#
# Epoch 00061: acc did not improve from 0.99919
# Epoch 62/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0745 - acc: 0.9990 - val_loss: 0.3525 - val_acc: 0.9834
#
# Epoch 00062: acc did not improve from 0.99919
# Epoch 00062: early stopping

# %%
import pandas as pd
df = pd.DataFrame(history.history)
df.head()
# losses[['acc','val_acc']].plot()
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,1,sharex=True, figsize=(10,8))
ax[0].plot(df['loss'],label = 'Training Loss')
ax[0].plot(df['val_loss'],label = 'Validation Loss')
ax[1].plot(df['acc'],label = 'Training Accuracy')
ax[1].plot(df['val_acc'],label = 'Validation Accuracy')
ax[0].legend(loc='best',prop={'size':12})
ax[1].legend(loc='best',prop={'size':12})
ax[0].minorticks_on()
ax[1].minorticks_on()
ax[1].set_xlabel('Epochs', fontsize=12)
ax[1].set_ylabel('Accuracy', fontsize=12)
ax[0].set_ylabel('Loss', fontsize=12)
ax[0].grid()
ax[1].grid()
plt.show()

#saving the results
df.to_csv('results.csv')




# print(history.history['val_loss'])
# print(history.history['val_acc'])
# print(history.history['acc'])
# print(history.history['loss'])

# %%
from sklearn.metrics import multilabel_confusion_matrix
#%%
prediction = resnet_model.predict_classes(x_test)

mcm = multilabel_confusion_matrix(y_true=y_test, y_pred=prediction, labels=[0,1,2,3], samplewise=False)
tn = mcm[:,0,0]
tp = mcm[:,1,1]
fp = mcm[:,0,1]
fn = mcm[:,1,0]
specificity = tn/(tn+fp)
print("Specificity or TNR", np.mean(specificity))

sensitivity = tp/(tp+fn)
print("Sensitivity or TPR or Recall", np.mean(sensitivity))

print("FNR ", 1-np.mean(sensitivity))

print("FPR", 1-np.mean(specificity))

from sklearn import metrics
print("Accuracy = ", metrics.accuracy_score(y_test, prediction))
#%%
# use model to predict probability that given y value is 1
y_pred_proba = resnet_model.predict_proba(x_test)

#calculate AUC of model
auc = metrics.roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

#print AUC score
print("AUC =",auc)

from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test, prediction)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7, 6))
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, cmap='Blues', cbar=False, linewidth=0.5,linecolor="black",fmt='')
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
# Out:
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Specificity or TNR 0.9682426577484531
# Sensitivity or TPR or Recall 0.9215479066022545
# FNR  0.0784520933977455
# FPR 0.031757342251546916
# Accuracy =  0.9047619047619048
# AUC = 0.9911532606304571
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:430: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Text(58.222222222222214, 0.5, 'True Label')
