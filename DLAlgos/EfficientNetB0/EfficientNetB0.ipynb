# %%
import numpy as np
import h5py

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\noush\OneDrive\Noushath Data\Research\Deep Learning Codes\Python Projects\IJNS2023\DLAlgos\EfficientNetB0

# %%
def load_OASIS():
    with h5py.File('..\..\Datasets\OASIS_balanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('trainX'))
        trainY = np.array(G1.get('trainY'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('testX'))
        testY = np.array(G2.get('testY'))

        return trainX, trainY, testX, testY

# %%
def load_ADNI():
    with h5py.File('..\..\Datasets\ADNI_enhanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('x_train'))
        trainY = np.array(G1.get('y_train'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('x_test'))
        testY = np.array(G2.get('y_test'))

        return trainX, trainY, testX, testY

# %%
dataset = 'ADNI'
#dataset = 'ADsNI'
# read the data which is also normalized.
if dataset == 'ADNI':
    x_train, y_train, x_test, y_test = load_ADNI()
else:
    x_train, y_train, x_test, y_test = load_OASIS()

print(x_train.shape, y_train.shape, x_test.shape,y_test.shape)
# Out:
# (940, 218, 182, 1) (940,) (105, 218, 182, 1) (105,)

# %%
#Dataset ready for deep learning
from tensorflow.keras.utils import to_categorical
#x_train = np.expand_dims(x_train, axis=-1)
x_train = np.repeat(x_train, 3, axis=3)

#x_test = np.expand_dims(x_test, axis=-1)
x_test = np.repeat(x_test, 3, axis=3)

y_train_cat = to_categorical(y_train, num_classes=4)
y_test_cat = to_categorical(y_test, num_classes=4)

print("Test",x_test.shape)
print ("Train",x_train.shape)
print(y_train.shape)
print (y_train_cat.shape)
print (y_test_cat.shape)
#print(np.max(x_train[0])) #to ensure that the values are within the range [0,1]
# Out:
# Test (105, 218, 182, 3)
# Train (940, 218, 182, 3)
# (940,)
# (940, 4)
# (105, 4)

# %%
print(x_test.shape)
print()
epochs = 10 #hyperparameter
num_classes=4
# Out:
# (105, 218, 182, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, MaxPooling2D, Activation, BatchNormalization
import tensorflow as tf
resnet_model = Sequential()


pretrained_model= tf.keras.applications.EfficientNetB0(include_top=False,
                   #input_shape=(176,176,3),
                   input_shape=(218,182,3),
                   pooling='avg',classes=4,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Dropout(0.5))
resnet_model.add(Flatten())
resnet_model.add(BatchNormalization())
resnet_model.add(Dense(2048,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(1024,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(4,activation='softmax'))
resnet_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb0 (Functional)  (None, 1280)              4049571
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1280)              5120
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              2623488
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation_2 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 8,792,743
# Trainable params: 4,734,468
# Non-trainable params: 4,058,275
# _________________________________________________________________

# %%
METRIC = tf.keras.metrics.AUC(name = 'acc')
from tensorflow.keras.optimizers import Adam # optimizer hyperparameter
resnet_model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=METRIC) #learning rate hyperparameter.

# %%
filepath = 'best_weights.hdf5'
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

earlystopping = EarlyStopping(monitor = 'acc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'acc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)
callback_list = [earlystopping, checkpoint]

# %%
#training
#batch_size hyperparamter.
history=resnet_model.fit(x_train, y_train_cat, batch_size = 128, epochs = 200, verbose = 1, validation_data = (x_test, y_test_cat), callbacks=callback_list)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 6s 307ms/step - loss: 1.7802 - acc: 0.5962 - val_loss: 1.3128 - val_acc: 0.6857
#
# Epoch 00001: acc improved from -inf to 0.59623, saving model to best_weights.hdf5
# Epoch 2/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.8432 - acc: 0.6290 - val_loss: 1.3181 - val_acc: 0.6364
#
# Epoch 00002: acc improved from 0.59623 to 0.62903, saving model to best_weights.hdf5
# Epoch 3/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.8261 - acc: 0.5817 - val_loss: 1.3462 - val_acc: 0.6519
#
# Epoch 00003: acc did not improve from 0.62903
# Epoch 4/200
# 8/8 [==============================] - 1s 178ms/step - loss: 1.8831 - acc: 0.5967 - val_loss: 1.3683 - val_acc: 0.5434
#
# Epoch 00004: acc did not improve from 0.62903
# Epoch 5/200
# 8/8 [==============================] - 1s 181ms/step - loss: 1.8148 - acc: 0.6030 - val_loss: 1.3312 - val_acc: 0.6033
#
# Epoch 00005: acc did not improve from 0.62903
# Epoch 6/200
# 8/8 [==============================] - 1s 171ms/step - loss: 1.8199 - acc: 0.5893 - val_loss: 1.3859 - val_acc: 0.5444
#
# Epoch 00006: acc did not improve from 0.62903
# Epoch 7/200
# 8/8 [==============================] - 1s 169ms/step - loss: 1.7072 - acc: 0.6230 - val_loss: 1.3739 - val_acc: 0.6092
#
# Epoch 00007: acc did not improve from 0.62903
# Epoch 8/200
# 8/8 [==============================] - 1s 168ms/step - loss: 1.7062 - acc: 0.6134 - val_loss: 1.3908 - val_acc: 0.6063
#
# Epoch 00008: acc did not improve from 0.62903
# Epoch 9/200
# 8/8 [==============================] - 1s 168ms/step - loss: 1.6572 - acc: 0.6108 - val_loss: 1.3735 - val_acc: 0.5550
#
# Epoch 00009: acc did not improve from 0.62903
# Epoch 10/200
# 8/8 [==============================] - 1s 168ms/step - loss: 1.6357 - acc: 0.6074 - val_loss: 1.3286 - val_acc: 0.6762
#
# Epoch 00010: acc did not improve from 0.62903
# Epoch 11/200
# 8/8 [==============================] - 1s 168ms/step - loss: 1.5868 - acc: 0.6220 - val_loss: 1.3643 - val_acc: 0.5468
#
# Epoch 00011: acc did not improve from 0.62903
# Epoch 12/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.5443 - acc: 0.6254 - val_loss: 1.3660 - val_acc: 0.6157
#
# Epoch 00012: acc did not improve from 0.62903
# Epoch 13/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.5726 - acc: 0.6137 - val_loss: 1.3630 - val_acc: 0.6159
#
# Epoch 00013: acc did not improve from 0.62903
# Epoch 14/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.5296 - acc: 0.6222 - val_loss: 1.3551 - val_acc: 0.6160
#
# Epoch 00014: acc did not improve from 0.62903
# Epoch 15/200
# 8/8 [==============================] - 1s 178ms/step - loss: 1.4982 - acc: 0.6209 - val_loss: 1.3471 - val_acc: 0.6160
#
# Epoch 00015: acc did not improve from 0.62903
# Epoch 16/200
# 8/8 [==============================] - 1s 182ms/step - loss: 1.4814 - acc: 0.6300 - val_loss: 1.3356 - val_acc: 0.6174
#
# Epoch 00016: acc improved from 0.62903 to 0.62995, saving model to best_weights.hdf5
# Epoch 17/200
# 8/8 [==============================] - 1s 179ms/step - loss: 1.5013 - acc: 0.6262 - val_loss: 1.3145 - val_acc: 0.6160
#
# Epoch 00017: acc did not improve from 0.62995
# Epoch 18/200
# 8/8 [==============================] - 1s 179ms/step - loss: 1.4730 - acc: 0.6305 - val_loss: 1.3169 - val_acc: 0.6166
#
# Epoch 00018: acc improved from 0.62995 to 0.63045, saving model to best_weights.hdf5
# Epoch 19/200
# 8/8 [==============================] - 1s 175ms/step - loss: 1.4294 - acc: 0.6396 - val_loss: 1.3140 - val_acc: 0.6152
#
# Epoch 00019: acc improved from 0.63045 to 0.63957, saving model to best_weights.hdf5
# Epoch 20/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3929 - acc: 0.6561 - val_loss: 1.2991 - val_acc: 0.6162
#
# Epoch 00020: acc improved from 0.63957 to 0.65607, saving model to best_weights.hdf5
# Epoch 21/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.4189 - acc: 0.6347 - val_loss: 1.2882 - val_acc: 0.6790
#
# Epoch 00021: acc did not improve from 0.65607
# Epoch 22/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3797 - acc: 0.6476 - val_loss: 1.2858 - val_acc: 0.6755
#
# Epoch 00022: acc did not improve from 0.65607
# Epoch 23/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.4180 - acc: 0.6498 - val_loss: 1.2803 - val_acc: 0.6755
#
# Epoch 00023: acc did not improve from 0.65607
# Epoch 24/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3953 - acc: 0.6351 - val_loss: 1.2742 - val_acc: 0.6762
#
# Epoch 00024: acc did not improve from 0.65607
# Epoch 25/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3936 - acc: 0.6558 - val_loss: 1.2727 - val_acc: 0.6758
#
# Epoch 00025: acc did not improve from 0.65607
# Epoch 26/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3885 - acc: 0.6459 - val_loss: 1.2731 - val_acc: 0.6762
#
# Epoch 00026: acc did not improve from 0.65607
# Epoch 27/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3680 - acc: 0.6410 - val_loss: 1.2693 - val_acc: 0.6766
#
# Epoch 00027: acc did not improve from 0.65607
# Epoch 28/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3367 - acc: 0.6702 - val_loss: 1.2582 - val_acc: 0.6741
#
# Epoch 00028: acc improved from 0.65607 to 0.67020, saving model to best_weights.hdf5
# Epoch 29/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3608 - acc: 0.6580 - val_loss: 1.2573 - val_acc: 0.6725
#
# Epoch 00029: acc did not improve from 0.67020
# Epoch 30/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3631 - acc: 0.6578 - val_loss: 1.2632 - val_acc: 0.6803
#
# Epoch 00030: acc did not improve from 0.67020
# Epoch 31/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3576 - acc: 0.6515 - val_loss: 1.2568 - val_acc: 0.6762
#
# Epoch 00031: acc did not improve from 0.67020
# Epoch 32/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3509 - acc: 0.6512 - val_loss: 1.2599 - val_acc: 0.6743
#
# Epoch 00032: acc did not improve from 0.67020
# Epoch 33/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3224 - acc: 0.6653 - val_loss: 1.2485 - val_acc: 0.6762
#
# Epoch 00033: acc did not improve from 0.67020
# Epoch 34/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3918 - acc: 0.6458 - val_loss: 1.2531 - val_acc: 0.6796
#
# Epoch 00034: acc did not improve from 0.67020
# Epoch 35/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3584 - acc: 0.6455 - val_loss: 1.2526 - val_acc: 0.6769
#
# Epoch 00035: acc did not improve from 0.67020
# Epoch 36/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3267 - acc: 0.6683 - val_loss: 1.2493 - val_acc: 0.6857
#
# Epoch 00036: acc did not improve from 0.67020
# Epoch 37/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3336 - acc: 0.6527 - val_loss: 1.2489 - val_acc: 0.6857
#
# Epoch 00037: acc did not improve from 0.67020
# Epoch 38/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3438 - acc: 0.6566 - val_loss: 1.2538 - val_acc: 0.6782
#
# Epoch 00038: acc did not improve from 0.67020
# Epoch 39/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3241 - acc: 0.6601 - val_loss: 1.2471 - val_acc: 0.6813
#
# Epoch 00039: acc did not improve from 0.67020
# Epoch 40/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3532 - acc: 0.6538 - val_loss: 1.2482 - val_acc: 0.6858
#
# Epoch 00040: acc did not improve from 0.67020
# Epoch 41/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3066 - acc: 0.6714 - val_loss: 1.2452 - val_acc: 0.6866
#
# Epoch 00041: acc improved from 0.67020 to 0.67142, saving model to best_weights.hdf5
# Epoch 42/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3291 - acc: 0.6552 - val_loss: 1.2464 - val_acc: 0.6848
#
# Epoch 00042: acc did not improve from 0.67142
# Epoch 43/200
# 8/8 [==============================] - 1s 175ms/step - loss: 1.3239 - acc: 0.6594 - val_loss: 1.2468 - val_acc: 0.6736
#
# Epoch 00043: acc did not improve from 0.67142
# Epoch 44/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3072 - acc: 0.6735 - val_loss: 1.2571 - val_acc: 0.6823
#
# Epoch 00044: acc improved from 0.67142 to 0.67346, saving model to best_weights.hdf5
# Epoch 45/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3041 - acc: 0.6715 - val_loss: 1.2480 - val_acc: 0.6850
#
# Epoch 00045: acc did not improve from 0.67346
# Epoch 46/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3125 - acc: 0.6623 - val_loss: 1.2547 - val_acc: 0.6883
#
# Epoch 00046: acc did not improve from 0.67346
# Epoch 47/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3244 - acc: 0.6666 - val_loss: 1.2491 - val_acc: 0.6841
#
# Epoch 00047: acc did not improve from 0.67346
# Epoch 48/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3083 - acc: 0.6706 - val_loss: 1.2463 - val_acc: 0.6857
#
# Epoch 00048: acc did not improve from 0.67346
# Epoch 49/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3198 - acc: 0.6571 - val_loss: 1.2506 - val_acc: 0.6863
#
# Epoch 00049: acc did not improve from 0.67346
# Epoch 50/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3212 - acc: 0.6708 - val_loss: 1.2534 - val_acc: 0.6857
#
# Epoch 00050: acc did not improve from 0.67346
# Epoch 51/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3116 - acc: 0.6590 - val_loss: 1.2444 - val_acc: 0.6853
#
# Epoch 00051: acc did not improve from 0.67346
# Epoch 52/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3063 - acc: 0.6656 - val_loss: 1.2653 - val_acc: 0.6840
#
# Epoch 00052: acc did not improve from 0.67346
# Epoch 53/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3153 - acc: 0.6752 - val_loss: 1.2481 - val_acc: 0.6841
#
# Epoch 00053: acc improved from 0.67346 to 0.67519, saving model to best_weights.hdf5
# Epoch 54/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3132 - acc: 0.6595 - val_loss: 1.2556 - val_acc: 0.6845
#
# Epoch 00054: acc did not improve from 0.67519
# Epoch 55/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3137 - acc: 0.6679 - val_loss: 1.2580 - val_acc: 0.6857
#
# Epoch 00055: acc did not improve from 0.67519
# Epoch 56/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.2963 - acc: 0.6708 - val_loss: 1.2460 - val_acc: 0.6879
#
# Epoch 00056: acc did not improve from 0.67519
# Epoch 57/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2958 - acc: 0.6702 - val_loss: 1.2535 - val_acc: 0.6857
#
# Epoch 00057: acc did not improve from 0.67519
# Epoch 58/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3017 - acc: 0.6716 - val_loss: 1.2653 - val_acc: 0.6857
#
# Epoch 00058: acc did not improve from 0.67519
# Epoch 59/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3151 - acc: 0.6671 - val_loss: 1.2551 - val_acc: 0.6853
#
# Epoch 00059: acc did not improve from 0.67519
# Epoch 60/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3059 - acc: 0.6616 - val_loss: 1.2508 - val_acc: 0.6860
#
# Epoch 00060: acc did not improve from 0.67519
# Epoch 61/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2926 - acc: 0.6704 - val_loss: 1.2512 - val_acc: 0.6857
#
# Epoch 00061: acc did not improve from 0.67519
# Epoch 62/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2801 - acc: 0.6817 - val_loss: 1.2594 - val_acc: 0.6849
#
# Epoch 00062: acc improved from 0.67519 to 0.68172, saving model to best_weights.hdf5
# Epoch 63/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3129 - acc: 0.6684 - val_loss: 1.2578 - val_acc: 0.6862
#
# Epoch 00063: acc did not improve from 0.68172
# Epoch 64/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3014 - acc: 0.6633 - val_loss: 1.2587 - val_acc: 0.6857
#
# Epoch 00064: acc did not improve from 0.68172
# Epoch 65/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.3024 - acc: 0.6716 - val_loss: 1.2543 - val_acc: 0.6901
#
# Epoch 00065: acc did not improve from 0.68172
# Epoch 66/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3077 - acc: 0.6638 - val_loss: 1.2703 - val_acc: 0.6853
#
# Epoch 00066: acc did not improve from 0.68172
# Epoch 67/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2971 - acc: 0.6706 - val_loss: 1.2534 - val_acc: 0.6879
#
# Epoch 00067: acc did not improve from 0.68172
# Epoch 68/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.2866 - acc: 0.6789 - val_loss: 1.2690 - val_acc: 0.6857
#
# Epoch 00068: acc did not improve from 0.68172
# Epoch 69/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2897 - acc: 0.6830 - val_loss: 1.2817 - val_acc: 0.6764
#
# Epoch 00069: acc improved from 0.68172 to 0.68298, saving model to best_weights.hdf5
# Epoch 70/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2856 - acc: 0.6742 - val_loss: 1.2582 - val_acc: 0.6857
#
# Epoch 00070: acc did not improve from 0.68298
# Epoch 71/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.2854 - acc: 0.6724 - val_loss: 1.2620 - val_acc: 0.6857
#
# Epoch 00071: acc did not improve from 0.68298
# Epoch 72/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.2830 - acc: 0.6808 - val_loss: 1.2658 - val_acc: 0.6857
#
# Epoch 00072: acc did not improve from 0.68298
# Epoch 73/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3007 - acc: 0.6676 - val_loss: 1.2558 - val_acc: 0.6857
#
# Epoch 00073: acc did not improve from 0.68298
# Epoch 74/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2742 - acc: 0.6810 - val_loss: 1.2809 - val_acc: 0.6845
#
# Epoch 00074: acc did not improve from 0.68298
# Epoch 75/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2892 - acc: 0.6786 - val_loss: 1.2746 - val_acc: 0.6857
#
# Epoch 00075: acc did not improve from 0.68298
# Epoch 76/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3048 - acc: 0.6640 - val_loss: 1.2556 - val_acc: 0.6856
#
# Epoch 00076: acc did not improve from 0.68298
# Epoch 77/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.2979 - acc: 0.6796 - val_loss: 1.3234 - val_acc: 0.6857
#
# Epoch 00077: acc did not improve from 0.68298
# Epoch 78/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3097 - acc: 0.6626 - val_loss: 1.2589 - val_acc: 0.6857
#
# Epoch 00078: acc did not improve from 0.68298
# Epoch 79/200
# 8/8 [==============================] - 1s 172ms/step - loss: 1.3089 - acc: 0.6705 - val_loss: 1.2500 - val_acc: 0.6890
#
# Epoch 00079: acc did not improve from 0.68298
# Epoch 80/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2875 - acc: 0.6734 - val_loss: 1.3214 - val_acc: 0.6907
#
# Epoch 00080: acc did not improve from 0.68298
# Epoch 81/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.3207 - acc: 0.6656 - val_loss: 1.2738 - val_acc: 0.6857
#
# Epoch 00081: acc did not improve from 0.68298
# Epoch 82/200
# 8/8 [==============================] - 1s 174ms/step - loss: 1.2887 - acc: 0.6801 - val_loss: 1.2618 - val_acc: 0.6796
#
# Epoch 00082: acc did not improve from 0.68298
# Epoch 83/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2927 - acc: 0.6701 - val_loss: 1.2791 - val_acc: 0.6762
#
# Epoch 00083: acc did not improve from 0.68298
# Epoch 84/200
# 8/8 [==============================] - 1s 173ms/step - loss: 1.2893 - acc: 0.6733 - val_loss: 1.2728 - val_acc: 0.6857
#
# Epoch 00084: acc did not improve from 0.68298
# Epoch 00084: early stopping

# %%
import pandas as pd
df = pd.DataFrame(history.history)
df.head()
# losses[['acc','val_acc']].plot()
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,1,sharex=True, figsize=(10,8))
ax[0].plot(df['loss'],label = 'Training Loss')
ax[0].plot(df['val_loss'],label = 'Validation Loss')
ax[1].plot(df['acc'],label = 'Training Accuracy')
ax[1].plot(df['val_acc'],label = 'Validation Accuracy')
ax[0].legend(loc='best',prop={'size':12})
ax[1].legend(loc='best',prop={'size':12})
ax[0].minorticks_on()
ax[1].minorticks_on()
ax[1].set_xlabel('Epochs', fontsize=12)
ax[1].set_ylabel('Accuracy', fontsize=12)
ax[0].set_ylabel('Loss', fontsize=12)
ax[0].grid()
ax[1].grid()
plt.show()

#saving the results
df.to_csv('results.csv')




# print(history.history['val_loss'])
# print(history.history['val_acc'])
# print(history.history['acc'])
# print(history.history['loss'])

# %%
from sklearn.metrics import multilabel_confusion_matrix
#%%
prediction = resnet_model.predict_classes(x_test)

mcm = multilabel_confusion_matrix(y_true=y_test, y_pred=prediction, labels=[0,1,2,3], samplewise=False)
tn = mcm[:,0,0]
tp = mcm[:,1,1]
fp = mcm[:,0,1]
fn = mcm[:,1,0]
specificity = tn/(tn+fp)
print("Specificity or TNR", np.mean(specificity))

sensitivity = tp/(tp+fn)
print("Sensitivity or TPR or Recall", np.mean(sensitivity))

print("FNR ", 1-np.mean(sensitivity))

print("FPR", 1-np.mean(specificity))

from sklearn import metrics
print("Accuracy = ", metrics.accuracy_score(y_test, prediction))
#%%
# use model to predict probability that given y value is 1
y_pred_proba = resnet_model.predict_proba(x_test)

#calculate AUC of model
auc = metrics.roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

#print AUC score
print("AUC =",auc)

from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test, prediction)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7, 6))
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, cmap='Blues', cbar=False, linewidth=0.5,linecolor="black",fmt='')
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
# Out:
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Specificity or TNR 0.75
# Sensitivity or TPR or Recall 0.25
# FNR  0.75
# FPR 0.25
# Accuracy =  0.4380952380952381
# AUC = 0.5468107806038762
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:430: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# Text(58.222222222222214, 0.5, 'True Label')
