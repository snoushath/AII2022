# %%
import numpy as np
import h5py

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\noush\OneDrive\Noushath Data\Research\Deep Learning Codes\Python Projects\IJNS2023\DLAlgos\ResNet101

# %%
def load_OASIS():
    with h5py.File('..\..\Datasets\OASIS_balanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('trainX'))
        trainY = np.array(G1.get('trainY'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('testX'))
        testY = np.array(G2.get('testY'))

        return trainX, trainY, testX, testY

# %%
def load_ADNI():
    with h5py.File('..\..\Datasets\ADNI_enhanced.h5', 'r') as hdf:

        G1 = hdf.get('Train Data')
        trainX = np.array(G1.get('x_train'))
        trainY = np.array(G1.get('y_train'))
        G2 = hdf.get('Test Data')
        testX = np.array(G2.get('x_test'))
        testY = np.array(G2.get('y_test'))

        return trainX, trainY, testX, testY

# %%
dataset = 'ADNI'
#dataset = 'ADsNI'
# read the data which is also normalized.
if dataset == 'ADNI':
    x_train, y_train, x_test, y_test = load_ADNI()
else:
    x_train, y_train, x_test, y_test = load_OASIS()

print(x_train.shape, y_train.shape, x_test.shape,y_test.shape)
# Out:
# (940, 218, 182, 1) (940,) (105, 218, 182, 1) (105,)

# %%
#Dataset ready for deep learning
from tensorflow.keras.utils import to_categorical
#x_train = np.expand_dims(x_train, axis=-1)
x_train = np.repeat(x_train, 3, axis=3)

#x_test = np.expand_dims(x_test, axis=-1)
x_test = np.repeat(x_test, 3, axis=3)

y_train_cat = to_categorical(y_train, num_classes=4)
y_test_cat = to_categorical(y_test, num_classes=4)

print("Test",x_test.shape)
print ("Train",x_train.shape)
print(y_train.shape)
print (y_train_cat.shape)
print (y_test_cat.shape)
#print(np.max(x_train[0])) #to ensure that the values are within the range [0,1]
# Out:
# Test (105, 218, 182, 3)
# Train (940, 218, 182, 3)
# (940,)
# (940, 4)
# (105, 4)

# %%
print(x_test.shape)
print()
epochs = 10 #hyperparameter
num_classes=4
# Out:
# (105, 218, 182, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, MaxPooling2D, Activation, BatchNormalization
import tensorflow as tf
resnet_model = Sequential()


pretrained_model= tf.keras.applications.ResNet101(include_top=False,
                   #input_shape=(176,176,3),
                   input_shape=(218,182,3),
                   pooling='avg',classes=4,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Dropout(0.5))
resnet_model.add(Flatten())
resnet_model.add(BatchNormalization())
resnet_model.add(Dense(2048,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(1024,kernel_initializer='he_uniform'))
resnet_model.add(BatchNormalization())
resnet_model.add(Activation('relu'))
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(4,activation='softmax'))
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet101 (Functional)       (None, 2048)              42658176
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 2048)              4196352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 48,977,284
# Trainable params: 6,308,868
# Non-trainable params: 42,668,416
# _________________________________________________________________

# %%
METRIC = tf.keras.metrics.AUC(name = 'acc')
from tensorflow.keras.optimizers import Adam # optimizer hyperparameter
resnet_model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=METRIC) #learning rate hyperparameter.

# %%
filepath = 'best_weights.hdf5'
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

earlystopping = EarlyStopping(monitor = 'acc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'acc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)
callback_list = [earlystopping, checkpoint]

# %%
#training
#batch_size hyperparamter.
history=resnet_model.fit(x_train, y_train_cat, batch_size = 128, epochs = 200, verbose = 1, validation_data = (x_test, y_test_cat), callbacks=callback_list)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 14s 846ms/step - loss: 1.6422 - acc: 0.6502 - val_loss: 1.4494 - val_acc: 0.6139
#
# Epoch 00001: acc improved from -inf to 0.65018, saving model to best_weights.hdf5
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/200
# 8/8 [==============================] - 3s 392ms/step - loss: 1.4550 - acc: 0.7373 - val_loss: 1.6338 - val_acc: 0.4736
#
# Epoch 00002: acc improved from 0.65018 to 0.73732, saving model to best_weights.hdf5
# Epoch 3/200
# 8/8 [==============================] - 3s 377ms/step - loss: 1.3998 - acc: 0.7549 - val_loss: 1.5042 - val_acc: 0.4953
#
# Epoch 00003: acc improved from 0.73732 to 0.75490, saving model to best_weights.hdf5
# Epoch 4/200
# 8/8 [==============================] - 3s 372ms/step - loss: 1.3679 - acc: 0.7724 - val_loss: 1.3785 - val_acc: 0.5353
#
# Epoch 00004: acc improved from 0.75490 to 0.77241, saving model to best_weights.hdf5
# Epoch 5/200
# 8/8 [==============================] - 3s 370ms/step - loss: 1.3688 - acc: 0.7706 - val_loss: 1.5031 - val_acc: 0.5281
#
# Epoch 00005: acc did not improve from 0.77241
# Epoch 6/200
# 8/8 [==============================] - 3s 371ms/step - loss: 1.2732 - acc: 0.7879 - val_loss: 1.4681 - val_acc: 0.5413
#
# Epoch 00006: acc improved from 0.77241 to 0.78788, saving model to best_weights.hdf5
# Epoch 7/200
# 8/8 [==============================] - 3s 371ms/step - loss: 1.2174 - acc: 0.8011 - val_loss: 1.2908 - val_acc: 0.7003
#
# Epoch 00007: acc improved from 0.78788 to 0.80108, saving model to best_weights.hdf5
# Epoch 8/200
# 8/8 [==============================] - 3s 370ms/step - loss: 1.1931 - acc: 0.8160 - val_loss: 1.2255 - val_acc: 0.7694
#
# Epoch 00008: acc improved from 0.80108 to 0.81596, saving model to best_weights.hdf5
# Epoch 9/200
# 8/8 [==============================] - 3s 371ms/step - loss: 1.1339 - acc: 0.8203 - val_loss: 1.2402 - val_acc: 0.7299
#
# Epoch 00009: acc improved from 0.81596 to 0.82034, saving model to best_weights.hdf5
# Epoch 10/200
# 8/8 [==============================] - 3s 372ms/step - loss: 1.1177 - acc: 0.8223 - val_loss: 1.1852 - val_acc: 0.7608
#
# Epoch 00010: acc improved from 0.82034 to 0.82231, saving model to best_weights.hdf5
# Epoch 11/200
# 8/8 [==============================] - 3s 370ms/step - loss: 1.0658 - acc: 0.8384 - val_loss: 1.1436 - val_acc: 0.7830
#
# Epoch 00011: acc improved from 0.82231 to 0.83844, saving model to best_weights.hdf5
# Epoch 12/200
# 8/8 [==============================] - 3s 371ms/step - loss: 1.0721 - acc: 0.8361 - val_loss: 1.1675 - val_acc: 0.7787
#
# Epoch 00012: acc did not improve from 0.83844
# Epoch 13/200
# 8/8 [==============================] - 3s 374ms/step - loss: 1.0091 - acc: 0.8484 - val_loss: 1.1807 - val_acc: 0.7787
#
# Epoch 00013: acc improved from 0.83844 to 0.84841, saving model to best_weights.hdf5
# Epoch 14/200
# 8/8 [==============================] - 3s 373ms/step - loss: 1.0207 - acc: 0.8445 - val_loss: 1.1729 - val_acc: 0.7838
#
# Epoch 00014: acc did not improve from 0.84841
# Epoch 15/200
# 8/8 [==============================] - 3s 400ms/step - loss: 0.9741 - acc: 0.8551 - val_loss: 1.1507 - val_acc: 0.7834
#
# Epoch 00015: acc improved from 0.84841 to 0.85512, saving model to best_weights.hdf5
# Epoch 16/200
# 8/8 [==============================] - 3s 378ms/step - loss: 0.9023 - acc: 0.8712 - val_loss: 1.1377 - val_acc: 0.7856
#
# Epoch 00016: acc improved from 0.85512 to 0.87116, saving model to best_weights.hdf5
# Epoch 17/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.8837 - acc: 0.8761 - val_loss: 1.1372 - val_acc: 0.7880
#
# Epoch 00017: acc improved from 0.87116 to 0.87607, saving model to best_weights.hdf5
# Epoch 18/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.9644 - acc: 0.8589 - val_loss: 1.1427 - val_acc: 0.7932
#
# Epoch 00018: acc did not improve from 0.87607
# Epoch 19/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.8978 - acc: 0.8704 - val_loss: 1.1438 - val_acc: 0.7956
#
# Epoch 00019: acc did not improve from 0.87607
# Epoch 20/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.7942 - acc: 0.8925 - val_loss: 1.1159 - val_acc: 0.7945
#
# Epoch 00020: acc improved from 0.87607 to 0.89254, saving model to best_weights.hdf5
# Epoch 21/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.8567 - acc: 0.8823 - val_loss: 1.1221 - val_acc: 0.7984
#
# Epoch 00021: acc did not improve from 0.89254
# Epoch 22/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.8492 - acc: 0.8842 - val_loss: 1.1285 - val_acc: 0.7997
#
# Epoch 00022: acc did not improve from 0.89254
# Epoch 23/200
# 8/8 [==============================] - 3s 362ms/step - loss: 0.8317 - acc: 0.8847 - val_loss: 1.1106 - val_acc: 0.8016
#
# Epoch 00023: acc did not improve from 0.89254
# Epoch 24/200
# 8/8 [==============================] - 3s 362ms/step - loss: 0.7879 - acc: 0.8963 - val_loss: 1.1055 - val_acc: 0.8025
#
# Epoch 00024: acc improved from 0.89254 to 0.89627, saving model to best_weights.hdf5
# Epoch 25/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.7884 - acc: 0.8969 - val_loss: 1.1201 - val_acc: 0.8010
#
# Epoch 00025: acc improved from 0.89627 to 0.89692, saving model to best_weights.hdf5
# Epoch 26/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.7921 - acc: 0.8974 - val_loss: 1.1146 - val_acc: 0.8034
#
# Epoch 00026: acc improved from 0.89692 to 0.89738, saving model to best_weights.hdf5
# Epoch 27/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.7559 - acc: 0.9025 - val_loss: 1.1138 - val_acc: 0.8039
#
# Epoch 00027: acc improved from 0.89738 to 0.90245, saving model to best_weights.hdf5
# Epoch 28/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.7896 - acc: 0.8972 - val_loss: 1.1206 - val_acc: 0.8041
#
# Epoch 00028: acc did not improve from 0.90245
# Epoch 29/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.7651 - acc: 0.9019 - val_loss: 1.1178 - val_acc: 0.8069
#
# Epoch 00029: acc did not improve from 0.90245
# Epoch 30/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.7301 - acc: 0.9111 - val_loss: 1.0951 - val_acc: 0.8102
#
# Epoch 00030: acc improved from 0.90245 to 0.91110, saving model to best_weights.hdf5
# Epoch 31/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.7640 - acc: 0.9019 - val_loss: 1.0711 - val_acc: 0.8124
#
# Epoch 00031: acc did not improve from 0.91110
# Epoch 32/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.7398 - acc: 0.9065 - val_loss: 1.0642 - val_acc: 0.8146
#
# Epoch 00032: acc did not improve from 0.91110
# Epoch 33/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.7311 - acc: 0.9092 - val_loss: 1.0303 - val_acc: 0.8208
#
# Epoch 00033: acc did not improve from 0.91110
# Epoch 34/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.7206 - acc: 0.9104 - val_loss: 1.0193 - val_acc: 0.8253
#
# Epoch 00034: acc did not improve from 0.91110
# Epoch 35/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.7351 - acc: 0.9102 - val_loss: 1.0065 - val_acc: 0.8293
#
# Epoch 00035: acc did not improve from 0.91110
# Epoch 36/200
# 8/8 [==============================] - 3s 363ms/step - loss: 0.7496 - acc: 0.9056 - val_loss: 1.0195 - val_acc: 0.8279
#
# Epoch 00036: acc did not improve from 0.91110
# Epoch 37/200
# 8/8 [==============================] - 3s 363ms/step - loss: 0.6911 - acc: 0.9173 - val_loss: 1.0344 - val_acc: 0.8256
#
# Epoch 00037: acc improved from 0.91110 to 0.91732, saving model to best_weights.hdf5
# Epoch 38/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.6808 - acc: 0.9193 - val_loss: 0.9944 - val_acc: 0.8329
#
# Epoch 00038: acc improved from 0.91732 to 0.91932, saving model to best_weights.hdf5
# Epoch 39/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.7191 - acc: 0.9140 - val_loss: 0.9966 - val_acc: 0.8333
#
# Epoch 00039: acc did not improve from 0.91932
# Epoch 40/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.6399 - acc: 0.9299 - val_loss: 0.9869 - val_acc: 0.8361
#
# Epoch 00040: acc improved from 0.91932 to 0.92990, saving model to best_weights.hdf5
# Epoch 41/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.7066 - acc: 0.9148 - val_loss: 0.9507 - val_acc: 0.8449
#
# Epoch 00041: acc did not improve from 0.92990
# Epoch 42/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.6774 - acc: 0.9208 - val_loss: 0.9302 - val_acc: 0.8508
#
# Epoch 00042: acc did not improve from 0.92990
# Epoch 43/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.6053 - acc: 0.9367 - val_loss: 0.9157 - val_acc: 0.8552
#
# Epoch 00043: acc improved from 0.92990 to 0.93673, saving model to best_weights.hdf5
# Epoch 44/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.6636 - acc: 0.9228 - val_loss: 0.9077 - val_acc: 0.8593
#
# Epoch 00044: acc did not improve from 0.93673
# Epoch 45/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.6346 - acc: 0.9299 - val_loss: 0.8901 - val_acc: 0.8643
#
# Epoch 00045: acc did not improve from 0.93673
# Epoch 46/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.6054 - acc: 0.9367 - val_loss: 0.8615 - val_acc: 0.8723
#
# Epoch 00046: acc did not improve from 0.93673
# Epoch 47/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.5748 - acc: 0.9422 - val_loss: 0.8472 - val_acc: 0.8764
#
# Epoch 00047: acc improved from 0.93673 to 0.94216, saving model to best_weights.hdf5
# Epoch 48/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.6045 - acc: 0.9364 - val_loss: 0.8300 - val_acc: 0.8855
#
# Epoch 00048: acc did not improve from 0.94216
# Epoch 49/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.6294 - acc: 0.9319 - val_loss: 0.8207 - val_acc: 0.8860
#
# Epoch 00049: acc did not improve from 0.94216
# Epoch 50/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.6196 - acc: 0.9353 - val_loss: 0.7957 - val_acc: 0.8917
#
# Epoch 00050: acc did not improve from 0.94216
# Epoch 51/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.6221 - acc: 0.9329 - val_loss: 0.7992 - val_acc: 0.8906
#
# Epoch 00051: acc did not improve from 0.94216
# Epoch 52/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.6096 - acc: 0.9353 - val_loss: 0.7946 - val_acc: 0.8930
#
# Epoch 00052: acc did not improve from 0.94216
# Epoch 53/200
# 8/8 [==============================] - 3s 363ms/step - loss: 0.5714 - acc: 0.9428 - val_loss: 0.8112 - val_acc: 0.8887
#
# Epoch 00053: acc improved from 0.94216 to 0.94277, saving model to best_weights.hdf5
# Epoch 54/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.6056 - acc: 0.9362 - val_loss: 0.7658 - val_acc: 0.8998
#
# Epoch 00054: acc did not improve from 0.94277
# Epoch 55/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.5633 - acc: 0.9441 - val_loss: 0.7916 - val_acc: 0.8928
#
# Epoch 00055: acc improved from 0.94277 to 0.94415, saving model to best_weights.hdf5
# Epoch 56/200
# 8/8 [==============================] - 3s 379ms/step - loss: 0.5473 - acc: 0.9470 - val_loss: 0.7689 - val_acc: 0.8973
#
# Epoch 00056: acc improved from 0.94415 to 0.94701, saving model to best_weights.hdf5
# Epoch 57/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.5909 - acc: 0.9390 - val_loss: 0.6966 - val_acc: 0.9163
#
# Epoch 00057: acc did not improve from 0.94701
# Epoch 58/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.5764 - acc: 0.9427 - val_loss: 0.6825 - val_acc: 0.9212
#
# Epoch 00058: acc did not improve from 0.94701
# Epoch 59/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.5877 - acc: 0.9395 - val_loss: 0.7093 - val_acc: 0.9168
#
# Epoch 00059: acc did not improve from 0.94701
# Epoch 60/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.5821 - acc: 0.9420 - val_loss: 0.6535 - val_acc: 0.9294
#
# Epoch 00060: acc did not improve from 0.94701
# Epoch 61/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.5543 - acc: 0.9464 - val_loss: 0.6258 - val_acc: 0.9346
#
# Epoch 00061: acc did not improve from 0.94701
# Epoch 62/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.5550 - acc: 0.9464 - val_loss: 0.6057 - val_acc: 0.9386
#
# Epoch 00062: acc did not improve from 0.94701
# Epoch 63/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.5755 - acc: 0.9431 - val_loss: 0.5987 - val_acc: 0.9396
#
# Epoch 00063: acc did not improve from 0.94701
# Epoch 64/200
# 8/8 [==============================] - 3s 363ms/step - loss: 0.5313 - acc: 0.9505 - val_loss: 0.5844 - val_acc: 0.9421
#
# Epoch 00064: acc improved from 0.94701 to 0.95052, saving model to best_weights.hdf5
# Epoch 65/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.5364 - acc: 0.9497 - val_loss: 0.6002 - val_acc: 0.9360
#
# Epoch 00065: acc did not improve from 0.95052
# Epoch 66/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.5135 - acc: 0.9546 - val_loss: 0.5664 - val_acc: 0.9456
#
# Epoch 00066: acc improved from 0.95052 to 0.95465, saving model to best_weights.hdf5
# Epoch 67/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.5018 - acc: 0.9559 - val_loss: 0.5442 - val_acc: 0.9509
#
# Epoch 00067: acc improved from 0.95465 to 0.95588, saving model to best_weights.hdf5
# Epoch 68/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.5109 - acc: 0.9544 - val_loss: 0.5401 - val_acc: 0.9512
#
# Epoch 00068: acc did not improve from 0.95588
# Epoch 69/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.5270 - acc: 0.9508 - val_loss: 0.5045 - val_acc: 0.9580
#
# Epoch 00069: acc did not improve from 0.95588
# Epoch 70/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.5357 - acc: 0.9493 - val_loss: 0.4786 - val_acc: 0.9628
#
# Epoch 00070: acc did not improve from 0.95588
# Epoch 71/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.5526 - acc: 0.9471 - val_loss: 0.4514 - val_acc: 0.9678
#
# Epoch 00071: acc did not improve from 0.95588
# Epoch 72/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.5084 - acc: 0.9551 - val_loss: 0.4695 - val_acc: 0.9639
#
# Epoch 00072: acc did not improve from 0.95588
# Epoch 73/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.5137 - acc: 0.9538 - val_loss: 0.4478 - val_acc: 0.9673
#
# Epoch 00073: acc did not improve from 0.95588
# Epoch 74/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.4849 - acc: 0.9589 - val_loss: 0.4196 - val_acc: 0.9720
#
# Epoch 00074: acc improved from 0.95588 to 0.95888, saving model to best_weights.hdf5
# Epoch 75/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.5019 - acc: 0.9560 - val_loss: 0.4182 - val_acc: 0.9718
#
# Epoch 00075: acc did not improve from 0.95888
# Epoch 76/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4523 - acc: 0.9640 - val_loss: 0.3866 - val_acc: 0.9764
#
# Epoch 00076: acc improved from 0.95888 to 0.96401, saving model to best_weights.hdf5
# Epoch 77/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4665 - acc: 0.9617 - val_loss: 0.3586 - val_acc: 0.9801
#
# Epoch 00077: acc did not improve from 0.96401
# Epoch 78/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.5115 - acc: 0.9541 - val_loss: 0.3385 - val_acc: 0.9829
#
# Epoch 00078: acc did not improve from 0.96401
# Epoch 79/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4317 - acc: 0.9677 - val_loss: 0.3416 - val_acc: 0.9814
#
# Epoch 00079: acc improved from 0.96401 to 0.96772, saving model to best_weights.hdf5
# Epoch 80/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4994 - acc: 0.9563 - val_loss: 0.3246 - val_acc: 0.9834
#
# Epoch 00080: acc did not improve from 0.96772
# Epoch 81/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4688 - acc: 0.9614 - val_loss: 0.3073 - val_acc: 0.9855
#
# Epoch 00081: acc did not improve from 0.96772
# Epoch 82/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.5082 - acc: 0.9552 - val_loss: 0.3075 - val_acc: 0.9853
#
# Epoch 00082: acc did not improve from 0.96772
# Epoch 83/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4422 - acc: 0.9656 - val_loss: 0.2894 - val_acc: 0.9876
#
# Epoch 00083: acc did not improve from 0.96772
# Epoch 84/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4373 - acc: 0.9663 - val_loss: 0.2796 - val_acc: 0.9876
#
# Epoch 00084: acc did not improve from 0.96772
# Epoch 85/200
# 8/8 [==============================] - 3s 371ms/step - loss: 0.4699 - acc: 0.9610 - val_loss: 0.2776 - val_acc: 0.9873
#
# Epoch 00085: acc did not improve from 0.96772
# Epoch 86/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4218 - acc: 0.9681 - val_loss: 0.2773 - val_acc: 0.9870
#
# Epoch 00086: acc improved from 0.96772 to 0.96812, saving model to best_weights.hdf5
# Epoch 87/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.4673 - acc: 0.9614 - val_loss: 0.2551 - val_acc: 0.9891
#
# Epoch 00087: acc did not improve from 0.96812
# Epoch 88/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4614 - acc: 0.9622 - val_loss: 0.2463 - val_acc: 0.9894
#
# Epoch 00088: acc did not improve from 0.96812
# Epoch 89/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4054 - acc: 0.9710 - val_loss: 0.2494 - val_acc: 0.9884
#
# Epoch 00089: acc improved from 0.96812 to 0.97104, saving model to best_weights.hdf5
# Epoch 90/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4097 - acc: 0.9704 - val_loss: 0.2521 - val_acc: 0.9885
#
# Epoch 00090: acc did not improve from 0.97104
# Epoch 91/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4395 - acc: 0.9657 - val_loss: 0.2457 - val_acc: 0.9884
#
# Epoch 00091: acc did not improve from 0.97104
# Epoch 92/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4580 - acc: 0.9629 - val_loss: 0.2400 - val_acc: 0.9889
#
# Epoch 00092: acc did not improve from 0.97104
# Epoch 93/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.4209 - acc: 0.9688 - val_loss: 0.2448 - val_acc: 0.9886
#
# Epoch 00093: acc did not improve from 0.97104
# Epoch 94/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.4124 - acc: 0.9710 - val_loss: 0.2480 - val_acc: 0.9879
#
# Epoch 00094: acc did not improve from 0.97104
# Epoch 95/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.4208 - acc: 0.9687 - val_loss: 0.2381 - val_acc: 0.9878
#
# Epoch 00095: acc did not improve from 0.97104
# Epoch 96/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3924 - acc: 0.9725 - val_loss: 0.2321 - val_acc: 0.9883
#
# Epoch 00096: acc improved from 0.97104 to 0.97250, saving model to best_weights.hdf5
# Epoch 97/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.4411 - acc: 0.9662 - val_loss: 0.2323 - val_acc: 0.9887
#
# Epoch 00097: acc did not improve from 0.97250
# Epoch 98/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4045 - acc: 0.9706 - val_loss: 0.2268 - val_acc: 0.9886
#
# Epoch 00098: acc did not improve from 0.97250
# Epoch 99/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4241 - acc: 0.9683 - val_loss: 0.2256 - val_acc: 0.9891
#
# Epoch 00099: acc did not improve from 0.97250
# Epoch 100/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.4265 - acc: 0.9675 - val_loss: 0.2210 - val_acc: 0.9890
#
# Epoch 00100: acc did not improve from 0.97250
# Epoch 101/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.3820 - acc: 0.9735 - val_loss: 0.2270 - val_acc: 0.9857
#
# Epoch 00101: acc improved from 0.97250 to 0.97353, saving model to best_weights.hdf5
# Epoch 102/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.3888 - acc: 0.9731 - val_loss: 0.2289 - val_acc: 0.9857
#
# Epoch 00102: acc did not improve from 0.97353
# Epoch 103/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3476 - acc: 0.9787 - val_loss: 0.2292 - val_acc: 0.9858
#
# Epoch 00103: acc improved from 0.97353 to 0.97871, saving model to best_weights.hdf5
# Epoch 104/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3850 - acc: 0.9736 - val_loss: 0.2337 - val_acc: 0.9854
#
# Epoch 00104: acc did not improve from 0.97871
# Epoch 105/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3805 - acc: 0.9741 - val_loss: 0.2415 - val_acc: 0.9847
#
# Epoch 00105: acc did not improve from 0.97871
# Epoch 106/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4016 - acc: 0.9716 - val_loss: 0.2346 - val_acc: 0.9847
#
# Epoch 00106: acc did not improve from 0.97871
# Epoch 107/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3353 - acc: 0.9800 - val_loss: 0.2330 - val_acc: 0.9849
#
# Epoch 00107: acc improved from 0.97871 to 0.97997, saving model to best_weights.hdf5
# Epoch 108/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3699 - acc: 0.9757 - val_loss: 0.2455 - val_acc: 0.9842
#
# Epoch 00108: acc did not improve from 0.97997
# Epoch 109/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.3811 - acc: 0.9736 - val_loss: 0.2326 - val_acc: 0.9851
#
# Epoch 00109: acc did not improve from 0.97997
# Epoch 110/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3619 - acc: 0.9764 - val_loss: 0.2196 - val_acc: 0.9865
#
# Epoch 00110: acc did not improve from 0.97997
# Epoch 111/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3651 - acc: 0.9766 - val_loss: 0.2167 - val_acc: 0.9898
#
# Epoch 00111: acc did not improve from 0.97997
# Epoch 112/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3999 - acc: 0.9718 - val_loss: 0.2170 - val_acc: 0.9902
#
# Epoch 00112: acc did not improve from 0.97997
# Epoch 113/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.3693 - acc: 0.9756 - val_loss: 0.2100 - val_acc: 0.9873
#
# Epoch 00113: acc did not improve from 0.97997
# Epoch 114/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.3432 - acc: 0.9788 - val_loss: 0.2136 - val_acc: 0.9900
#
# Epoch 00114: acc did not improve from 0.97997
# Epoch 115/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3613 - acc: 0.9767 - val_loss: 0.2068 - val_acc: 0.9878
#
# Epoch 00115: acc did not improve from 0.97997
# Epoch 116/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3678 - acc: 0.9756 - val_loss: 0.2070 - val_acc: 0.9877
#
# Epoch 00116: acc did not improve from 0.97997
# Epoch 117/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3507 - acc: 0.9781 - val_loss: 0.2047 - val_acc: 0.9875
#
# Epoch 00117: acc did not improve from 0.97997
# Epoch 118/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3386 - acc: 0.9796 - val_loss: 0.2079 - val_acc: 0.9873
#
# Epoch 00118: acc did not improve from 0.97997
# Epoch 119/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.3689 - acc: 0.9753 - val_loss: 0.2090 - val_acc: 0.9875
#
# Epoch 00119: acc did not improve from 0.97997
# Epoch 120/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.3524 - acc: 0.9770 - val_loss: 0.2024 - val_acc: 0.9881
#
# Epoch 00120: acc did not improve from 0.97997
# Epoch 121/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3265 - acc: 0.9811 - val_loss: 0.2078 - val_acc: 0.9878
#
# Epoch 00121: acc improved from 0.97997 to 0.98105, saving model to best_weights.hdf5
# Epoch 122/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.3396 - acc: 0.9788 - val_loss: 0.2189 - val_acc: 0.9860
#
# Epoch 00122: acc did not improve from 0.98105
# Epoch 123/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3532 - acc: 0.9776 - val_loss: 0.2200 - val_acc: 0.9853
#
# Epoch 00123: acc did not improve from 0.98105
# Epoch 124/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3513 - acc: 0.9777 - val_loss: 0.2186 - val_acc: 0.9855
#
# Epoch 00124: acc did not improve from 0.98105
# Epoch 125/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.3038 - acc: 0.9834 - val_loss: 0.2168 - val_acc: 0.9870
#
# Epoch 00125: acc improved from 0.98105 to 0.98342, saving model to best_weights.hdf5
# Epoch 126/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.3397 - acc: 0.9787 - val_loss: 0.2089 - val_acc: 0.9870
#
# Epoch 00126: acc did not improve from 0.98342
# Epoch 127/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3411 - acc: 0.9780 - val_loss: 0.2032 - val_acc: 0.9875
#
# Epoch 00127: acc did not improve from 0.98342
# Epoch 128/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.2951 - acc: 0.9834 - val_loss: 0.1953 - val_acc: 0.9881
#
# Epoch 00128: acc did not improve from 0.98342
# Epoch 129/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3056 - acc: 0.9836 - val_loss: 0.1860 - val_acc: 0.9888
#
# Epoch 00129: acc improved from 0.98342 to 0.98362, saving model to best_weights.hdf5
# Epoch 130/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.3030 - acc: 0.9831 - val_loss: 0.1839 - val_acc: 0.9889
#
# Epoch 00130: acc did not improve from 0.98362
# Epoch 131/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3028 - acc: 0.9828 - val_loss: 0.1966 - val_acc: 0.9883
#
# Epoch 00131: acc did not improve from 0.98362
# Epoch 132/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3396 - acc: 0.9794 - val_loss: 0.2063 - val_acc: 0.9882
#
# Epoch 00132: acc did not improve from 0.98362
# Epoch 133/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3104 - acc: 0.9829 - val_loss: 0.2025 - val_acc: 0.9888
#
# Epoch 00133: acc did not improve from 0.98362
# Epoch 134/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.3263 - acc: 0.9804 - val_loss: 0.1899 - val_acc: 0.9891
#
# Epoch 00134: acc did not improve from 0.98362
# Epoch 135/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2978 - acc: 0.9844 - val_loss: 0.1864 - val_acc: 0.9891
#
# Epoch 00135: acc improved from 0.98362 to 0.98436, saving model to best_weights.hdf5
# Epoch 136/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.3395 - acc: 0.9785 - val_loss: 0.1819 - val_acc: 0.9892
#
# Epoch 00136: acc did not improve from 0.98436
# Epoch 137/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.2841 - acc: 0.9854 - val_loss: 0.1909 - val_acc: 0.9891
#
# Epoch 00137: acc improved from 0.98436 to 0.98535, saving model to best_weights.hdf5
# Epoch 138/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3032 - acc: 0.9831 - val_loss: 0.1978 - val_acc: 0.9892
#
# Epoch 00138: acc did not improve from 0.98535
# Epoch 139/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.2796 - acc: 0.9854 - val_loss: 0.1966 - val_acc: 0.9892
#
# Epoch 00139: acc improved from 0.98535 to 0.98542, saving model to best_weights.hdf5
# Epoch 140/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.2932 - acc: 0.9837 - val_loss: 0.1809 - val_acc: 0.9897
#
# Epoch 00140: acc did not improve from 0.98542
# Epoch 141/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.2781 - acc: 0.9854 - val_loss: 0.1755 - val_acc: 0.9902
#
# Epoch 00141: acc did not improve from 0.98542
# Epoch 142/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.2748 - acc: 0.9865 - val_loss: 0.1774 - val_acc: 0.9898
#
# Epoch 00142: acc improved from 0.98542 to 0.98649, saving model to best_weights.hdf5
# Epoch 143/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.2958 - acc: 0.9836 - val_loss: 0.1992 - val_acc: 0.9889
#
# Epoch 00143: acc did not improve from 0.98649
# Epoch 144/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.3080 - acc: 0.9824 - val_loss: 0.2155 - val_acc: 0.9873
#
# Epoch 00144: acc did not improve from 0.98649
# Epoch 145/200
# 8/8 [==============================] - 3s 376ms/step - loss: 0.2889 - acc: 0.9847 - val_loss: 0.2195 - val_acc: 0.9886
#
# Epoch 00145: acc did not improve from 0.98649
# Epoch 146/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3031 - acc: 0.9830 - val_loss: 0.2030 - val_acc: 0.9890
#
# Epoch 00146: acc did not improve from 0.98649
# Epoch 147/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.2943 - acc: 0.9843 - val_loss: 0.1947 - val_acc: 0.9893
#
# Epoch 00147: acc did not improve from 0.98649
# Epoch 148/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2802 - acc: 0.9855 - val_loss: 0.1909 - val_acc: 0.9895
#
# Epoch 00148: acc did not improve from 0.98649
# Epoch 149/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.2609 - acc: 0.9874 - val_loss: 0.1779 - val_acc: 0.9898
#
# Epoch 00149: acc improved from 0.98649 to 0.98737, saving model to best_weights.hdf5
# Epoch 150/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.3032 - acc: 0.9831 - val_loss: 0.1716 - val_acc: 0.9896
#
# Epoch 00150: acc did not improve from 0.98737
# Epoch 151/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.2525 - acc: 0.9880 - val_loss: 0.1706 - val_acc: 0.9895
#
# Epoch 00151: acc improved from 0.98737 to 0.98804, saving model to best_weights.hdf5
# Epoch 152/200
# 8/8 [==============================] - 3s 375ms/step - loss: 0.2285 - acc: 0.9903 - val_loss: 0.1540 - val_acc: 0.9904
#
# Epoch 00152: acc improved from 0.98804 to 0.99027, saving model to best_weights.hdf5
# Epoch 153/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.2593 - acc: 0.9869 - val_loss: 0.1505 - val_acc: 0.9905
#
# Epoch 00153: acc did not improve from 0.99027
# Epoch 154/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.2427 - acc: 0.9889 - val_loss: 0.1523 - val_acc: 0.9904
#
# Epoch 00154: acc did not improve from 0.99027
# Epoch 155/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.2665 - acc: 0.9866 - val_loss: 0.1495 - val_acc: 0.9908
#
# Epoch 00155: acc did not improve from 0.99027
# Epoch 156/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.2802 - acc: 0.9858 - val_loss: 0.1500 - val_acc: 0.9909
#
# Epoch 00156: acc did not improve from 0.99027
# Epoch 157/200
# 8/8 [==============================] - 3s 368ms/step - loss: 0.2697 - acc: 0.9863 - val_loss: 0.1513 - val_acc: 0.9906
#
# Epoch 00157: acc did not improve from 0.99027
# Epoch 158/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.2576 - acc: 0.9878 - val_loss: 0.1544 - val_acc: 0.9905
#
# Epoch 00158: acc did not improve from 0.99027
# Epoch 159/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2771 - acc: 0.9857 - val_loss: 0.1465 - val_acc: 0.9909
#
# Epoch 00159: acc did not improve from 0.99027
# Epoch 160/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2209 - acc: 0.9913 - val_loss: 0.1445 - val_acc: 0.9911
#
# Epoch 00160: acc improved from 0.99027 to 0.99133, saving model to best_weights.hdf5
# Epoch 161/200
# 8/8 [==============================] - 3s 370ms/step - loss: 0.2300 - acc: 0.9902 - val_loss: 0.1459 - val_acc: 0.9911
#
# Epoch 00161: acc did not improve from 0.99133
# Epoch 162/200
# 8/8 [==============================] - 3s 372ms/step - loss: 0.2640 - acc: 0.9875 - val_loss: 0.1471 - val_acc: 0.9909
#
# Epoch 00162: acc did not improve from 0.99133
# Epoch 163/200
# 8/8 [==============================] - 3s 374ms/step - loss: 0.2398 - acc: 0.9894 - val_loss: 0.1563 - val_acc: 0.9911
#
# Epoch 00163: acc did not improve from 0.99133
# Epoch 164/200
# 8/8 [==============================] - 3s 373ms/step - loss: 0.2670 - acc: 0.9872 - val_loss: 0.1688 - val_acc: 0.9908
#
# Epoch 00164: acc did not improve from 0.99133
# Epoch 165/200
# 8/8 [==============================] - 3s 367ms/step - loss: 0.2703 - acc: 0.9862 - val_loss: 0.1610 - val_acc: 0.9903
#
# Epoch 00165: acc did not improve from 0.99133
# Epoch 166/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2600 - acc: 0.9876 - val_loss: 0.1668 - val_acc: 0.9896
#
# Epoch 00166: acc did not improve from 0.99133
# Epoch 167/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.2584 - acc: 0.9871 - val_loss: 0.1641 - val_acc: 0.9898
#
# Epoch 00167: acc did not improve from 0.99133
# Epoch 168/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.2509 - acc: 0.9887 - val_loss: 0.1652 - val_acc: 0.9900
#
# Epoch 00168: acc did not improve from 0.99133
# Epoch 169/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.2601 - acc: 0.9867 - val_loss: 0.1508 - val_acc: 0.9907
#
# Epoch 00169: acc did not improve from 0.99133
# Epoch 170/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.2524 - acc: 0.9885 - val_loss: 0.1519 - val_acc: 0.9905
#
# Epoch 00170: acc did not improve from 0.99133
# Epoch 171/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2272 - acc: 0.9902 - val_loss: 0.1606 - val_acc: 0.9902
#
# Epoch 00171: acc did not improve from 0.99133
# Epoch 172/200
# 8/8 [==============================] - 3s 364ms/step - loss: 0.2535 - acc: 0.9881 - val_loss: 0.1563 - val_acc: 0.9910
#
# Epoch 00172: acc did not improve from 0.99133
# Epoch 173/200
# 8/8 [==============================] - 3s 366ms/step - loss: 0.2306 - acc: 0.9903 - val_loss: 0.1570 - val_acc: 0.9910
#
# Epoch 00173: acc did not improve from 0.99133
# Epoch 174/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2363 - acc: 0.9895 - val_loss: 0.1580 - val_acc: 0.9901
#
# Epoch 00174: acc did not improve from 0.99133
# Epoch 175/200
# 8/8 [==============================] - 3s 365ms/step - loss: 0.2401 - acc: 0.9895 - val_loss: 0.1558 - val_acc: 0.9902
#
# Epoch 00175: acc did not improve from 0.99133
# Epoch 00175: early stopping

# %%
import pandas as pd
df = pd.DataFrame(history.history)
df.head()
# losses[['acc','val_acc']].plot()
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2,1,sharex=True, figsize=(10,8))
ax[0].plot(df['loss'],label = 'Training Loss')
ax[0].plot(df['val_loss'],label = 'Validation Loss')
ax[1].plot(df['acc'],label = 'Training Accuracy')
ax[1].plot(df['val_acc'],label = 'Validation Accuracy')
ax[0].legend(loc='best',prop={'size':12})
ax[1].legend(loc='best',prop={'size':12})
ax[0].minorticks_on()
ax[1].minorticks_on()
ax[1].set_xlabel('Epochs', fontsize=12)
ax[1].set_ylabel('Accuracy', fontsize=12)
ax[0].set_ylabel('Loss', fontsize=12)
ax[0].grid()
ax[1].grid()
plt.show()

#saving the results
df.to_csv('results.csv')




# print(history.history['val_loss'])
# print(history.history['val_acc'])
# print(history.history['acc'])
# print(history.history['loss'])

# %%
from sklearn.metrics import multilabel_confusion_matrix
#%%
prediction = resnet_model.predict_classes(x_test)

mcm = multilabel_confusion_matrix(y_true=y_test, y_pred=prediction, labels=[0,1,2,3], samplewise=False)
tn = mcm[:,0,0]
tp = mcm[:,1,1]
fp = mcm[:,0,1]
fn = mcm[:,1,0]
specificity = tn/(tn+fp)
print("Specificity or TNR", np.mean(specificity))

sensitivity = tp/(tp+fn)
print("Sensitivity or TPR or Recall", np.mean(sensitivity))

print("FNR ", 1-np.mean(sensitivity))

print("FPR", 1-np.mean(specificity))

from sklearn import metrics
print("Accuracy = ", metrics.accuracy_score(y_test, prediction))
#%%
# use model to predict probability that given y value is 1
y_pred_proba = resnet_model.predict_proba(x_test)

#calculate AUC of model
auc = metrics.roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

#print AUC score
print("AUC =",auc)

from sklearn.metrics import confusion_matrix
import seaborn as sns
cf_matrix = confusion_matrix(y_test, prediction)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7, 6))
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, cmap='Blues', cbar=False, linewidth=0.5,linecolor="black",fmt='')
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('True Label', fontsize=12)
# Out:
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Specificity or TNR 0.986266035701064
# Sensitivity or TPR or Recall 0.9694545088566828
# FNR  0.03054549114331717
# FPR 0.01373396429893603
# Accuracy =  0.9619047619047619
# c:\Users\noush\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\keras\engine\sequential.py:430: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# AUC = 0.9922136688568973
# Text(58.222222222222214, 0.5, 'True Label')
